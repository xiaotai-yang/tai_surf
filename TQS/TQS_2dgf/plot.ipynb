# %%
import numpy as np
import matplotlib.pyplot as plt
E1 = np.load("result/meanE_L4_units128_cmi_pattern_no_decayrotationTrueangle1.5707964_seed3_patch4.npy")
E2 = np.load("result/meanE_L8_units32_cmi_pattern_no_decayrotationTrueangle0.0_seed3_patch1.npy")
E3 = np.load("result/meanE_L4_units32_cmi_pattern_no_decayrotationTrueangle1.5707964_seed3_patch1.npy")

# %%
plt.plot(E3)
