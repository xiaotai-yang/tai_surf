# %%
import numpy as np
a = np.random.uniform(-1, 1, 1000)
b = np.random.uniform(-1, 1, 1000)
(a @ b)/(np.linalg.norm(a)*np.linalg.norm(b))
# Out:
# -0.014909998244989842

# %%
eimport jax, jax.numpy as jnp
initializer = jax.nn.initializers.lecun_normal(in_axis= -2 , out_axis= -1, batch_axis= (0, 1))
initializer(jax.random.key(42), (2, 2, 10, 2), jnp.float32)
# Out:
# Array([[[[ 0.18091135,  0.17015879],
#          [-0.09812663,  0.49079546],
#          [-0.21932074,  0.45231673],
#          [ 0.01428061, -0.3218579 ],
#          [-0.08306615,  0.33559626],
#          [ 0.15759896,  0.124874  ],
#          [ 0.6622459 ,  0.09032162],
#          [-0.58407795,  0.01798202],
#          [-0.35047197, -0.20490287],
#          [-0.42977458, -0.15952592]],
#
#         [[-0.29425082,  0.0768541 ],
#          [ 0.20159037,  0.19402157],
#          [-0.3052951 ,  0.46351093],
#          [-0.1859521 , -0.21290292],
#          [ 0.22640783, -0.25817227],
#          [-0.21632487, -0.13316551],
#          [ 0.17738147,  0.5496517 ],
#          [ 0.02036353, -0.2196222 ],
#          [-0.61519676,  0.19275673],
#          [-0.50902236, -0.11977039]]],
#
#
#        [[[ 0.35093054, -0.06381734],
#          [-0.02972015, -0.0035028 ],
#          [ 0.22937167, -0.27439946],
#          [-0.3382934 , -0.41676888],
#          [ 0.27423018,  0.04086377],
# ...

# %%
b = np.sqrt(np.tan(np.random.uniform(0.0001, 0.1, 1000000)))
1/ (1 + b **2)
# Out:
# array([0.9187159 , 0.91083996, 0.97065805, ..., 0.99359235, 0.9254434 ,
#        0.92495061])

# %%
import matplotlib.pyplot as plt
plt.hist(1/ (1 + (b) **2), bins = 100)
# Out:
# (array([11035., 10947., 10804., 10676., 10843., 10647., 10942., 10743.,
#         10600., 10824., 10680., 10600., 10704., 10719., 10479., 10612.,
#         10620., 10430., 10425., 10618., 10528., 10566., 10603., 10622.,
#         10517., 10433., 10484., 10478., 10461., 10475., 10450., 10425.,
#         10295., 10267., 10304., 10399., 10248., 10075., 10010., 10165.,
#         10257., 10210., 10251., 10031., 10124., 10346., 10089., 10216.,
#         10033.,  9969.,  9815.,  9825.,  9975.,  9915., 10001.,  9860.,
#          9863.,  9886.,  9934.,  9850.,  9830.,  9932.,  9832.,  9899.,
#          9630.,  9692.,  9731.,  9753.,  9631.,  9620.,  9538.,  9519.,
#          9508.,  9576.,  9742.,  9523.,  9513.,  9519.,  9437.,  9216.,
#          9337.,  9469.,  9244.,  9395.,  9343.,  9345.,  9300.,  9296.,
#          9315.,  9394.,  9377.,  9249.,  9250.,  9240.,  9166.,  9087.,
#          9163.,  9103.,  8995.,  9088.]),
# ...
