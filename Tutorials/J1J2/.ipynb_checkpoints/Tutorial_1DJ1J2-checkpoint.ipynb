# %% [markdown]
# # Tutorial: Ground State of 1D J1-J2 Model with RNN wavefunctions
#
# Code by **Mohamed Hibat Allah** and **Martin Ganahl**.

# %% [markdown]
# **This notebook is intended to help the reader to get familiarized with Exact Diagonalization (ED) and Complex Recurrent Neural Networks (cRNN) wavefunctions. Here, we just explore small system sizes for pedagogical purposes and to keep the running time very short.**
#
# Check if you specifying the right "path" below to the google colab notebook on Drive to make sure everything below is working properly
#
# Make sure also you use a GPU by going to "Runtime/Change Runtime type" in Google Colaboratory to get a speedup

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
import sys
sys.path.append('gdrive/My Drive/RNNWavefunctions/RNNWavefunctions-master/J1J2')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import tensorflow as tf
def heavyside(inputs):
    sign = tf.sign(tf.sign(inputs) + 0.1 ) #tf.sign(0) = 0, this is a way to cure that since I want tf.sign(0) = 1
    return 0.5*(sign+1.0)
with tf.Session() as sess:
    a = sess.run(heavyside(-0.1))
    print(a)
# Out:
# 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import rcParams
rcParams['axes.labelsize']  = 20
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 10
rcParams['legend.fontsize'] = 20
rcParams['xtick.labelsize'] = 20
rcParams['ytick.labelsize'] = 20

# %% [markdown]
# ## **Calculating the ground state energy of 1D J1J2 using Exact Diagonalization (ED)**

# %% [markdown]
# Here, we attempt to calculate the ground state and the ground state energy of the 1D J1-J2 mode with Open Boundary Conditions using Exact diagonalization.
#
# The Hamiltonian is given as follows:
#
# $$     \hat{H}_{J_1J_2} = J_1 \sum_{\langle i,j \rangle} \hat{{\bf S}}_i \cdot \hat{{\bf S}}_{j} + J_2 \sum_{\langle \langle i,j \rangle \rangle} \hat{{\bf S}}_i \cdot \hat{{\bf S}}_{j}.
#  $$
#
# where ${\bf S}_i$ is a spin-1/2 operator.  Here,
# $\langle i,j \rangle$ and $\langle \langle i,j \rangle \rangle$ denote
# nearest and next-to-nearest neighbor pairs, respectively.

# %%
import numpy as np
def J1J2MatrixElements(J1,J2,Bz,sigmap, periodic = False):

    """
    computes the matrix element of the 1D J1-J2 model for a given state sigmap
    -----------------------------------------------------------------------------------
    Parameters:
    J1, J2: np.ndarray of shape (N), respectively, and dtype=float:
                Ising parameters
    sigmap:     np.ndarrray of dtype=int and shape (N)
                spin-state, integer encoded (using 0 for down spin and 1 for up spin)
                A sample of spins can be fed here.
    Bx: Transvers magnetic field (N)
    periodic: False = open boundary conditions and True = periodic boundary conditions
    -----------------------------------------------------------------------------------            
    Returns: 2-tuple of type (np.ndarray,np.ndarray)
             sigmas:         np.ndarray of dtype=int and shape (?,N)
                             the states for which there exist non-zero matrix elements for given sigmap
             matrixelements: np.ndarray of dtype=float and shape (?)
                             the non-zero matrix elements
    """

    sigmas=[]
    matrixelements=[]
    N=len(Bz)
    #the diagonal part is simply the sum of all Sz-Sz interactions plus a B field
    diag=np.dot(sigmap-0.5,Bz)

    if periodic:
        limit = N
    else:
        limit = N-1

    for site in range(limit):
        if sigmap[site]!=sigmap[(site+1)%N]: #if the two neighouring spins are opposite
            diag-=0.25*J1[site] #add a negative energy contribution
        else:
            diag+=0.25*J1[site]
        if site<(limit-1) and J2[site] != 0.0:
            if sigmap[site]!=sigmap[(site+2)%N]: #if the two second neighouring spins are opposite
                diag-=0.25*J2[site] #add a negative energy contribution
            else:
                diag+=0.25*J2[site]
    matrixelements.append(diag) #add the diagonal part to the matrix elements
    sigmas.append(np.copy(sigmap))

    #off-diagonal part:
    for site in range(limit):
        if J1[site] != 0.0:
            if sigmap[site]!=sigmap[(site+1)%N]:
                sig=np.copy(sigmap)
                sig[site]=sig[(site+1)%N] #Make the two neighbouring spins equal.
                sig[(site+1)%N]=sigmap[site]
                sigmas.append(sig) #The last fours lines are meant to flip the two neighbouring spins (that the effect of applying J+ and J-)
                matrixelements.append(J1[site]/2)
    for site in range(limit-1):
        if J2[site] != 0.0:
            if sigmap[site]!=sigmap[(site+2)%N]:
                sig=np.copy(sigmap)
                sig[site]=sig[(site+2)%N] #Make the two neighbouring spins equal.
                sig[(site+2)%N]=sigmap[site]
                sigmas.append(sig) #The last fours lines are meant to flip the two neighbouring spins (that the effect of applying J+ and J-)
                matrixelements.append(J2[site]/2)

    return np.array(sigmas),np.array(matrixelements)


def ED_j1j2(N,j1 = 1.0,j2 =0.0, periodic=False):
    """
    Returns a tuple (eta,U)
      eta = a list of energy eigenvalues.
      U = a list of energy eigenvectors
    """
    basis = []

    #Generate a basis
    for i in range(2**N):
        basis_temp = np.zeros((N))
        a = np.array([int(d) for d in bin(i)[2:]])
        l = len(a)
        basis_temp[N-l:] = a

        basis.append(basis_temp)

    basis = np.array(basis)


    J1=j1*np.ones(N)
    J2=j2*np.ones(N)
    Bz=np.zeros(N)

    H=np.zeros((basis.shape[0],basis.shape[0])) #prepare the hamiltonian
    for n in range(basis.shape[0]):
        sigmas,elements=J1J2MatrixElements(J1,J2,Bz,np.reshape(basis[n,:],(N)),periodic) # choose one basis for calculating energy
        
        for m in range(sigmas.shape[0]):     # the configuration that contributes to the energy
            for b in range(basis.shape[0]):
                if np.all(basis[b,:]==sigmas[m,:]):
                    H[b,n]=elements[m]
    eta,U=np.linalg.eigh(H) #diagonalize
    return eta,U

# %%
n_14_exact_j2_45 = ED_j1j2(14, j2=0.45)
np.save("n_14_exact_j2_0.45", n_14_exact_j2_45)
n_14_exact_j2_50 = ED_j1j2(14, j2=0.5)
np.save("n_14_exact_j2_0.50", n_14_exact_j2_50)
n_14_exact_j2_55 = ED_j1j2(14, j2=0.55)
np.save("n_14_exact_j2_0.55", n_14_exact_j2_55)

# %% [markdown]
# It may take some time to do exact diagonalization. You can try up to $N=12$ spins otherwise you have to wait for a very long time.
#
# Here we choose $J_2 = 0.2$, you are encouraged to try other values if you are curious.

# %%
N=5
eta,U=ED_j1j2(N, j1 = 1.0, j2=0.2, periodic = False)

print('the ground state energy is:')
E_exact = min(eta)
print(E_exact)
# Out:
# the ground state energy is:
# -1.817066119604269

# %% [markdown]
# ## **Representing the ground state**

# %% [markdown]
# Sometimes it is useful to represent the ground state in a plot as shown below, to know some information about the properties of the ground state, such as symmetries, sign of the amplitudes,...

# %%
fig, ax = plt.subplots(figsize=(10,6))

ground_state = U[:,np.nonzero(eta==np.min(eta))[0][0]]

plt.plot(ground_state,label="Ground state")

ax.set_xlabel(r'Basis index', fontsize = 25)
ax.set_ylabel('Amplitude', fontsize = 25)

plt.show()

# %% [markdown]
# We notice here that the amplitudes of the ground state in the z-basis change the sign, hence we can use a complex recurrent neural network wavefunction (cRNN wavefunction) to take account of the fluctuating sign.

# %% [markdown]
# ## **Calculating the ground state energy using an RNN wavefunction**

# %% [markdown]
# After that we obtained the ground state energy from exact diagonalization, we are going to value as a reference to assess the quality of the variational energy calculated by the cRNN wavefunction.
#
# Here we choose $J_2 = 0.2$ in the same way as exact diagonalization above.

# %%
from TrainingRNN_J1J2 import run_J1J2

#numsteps = number of training iterations
#systemsize = the number of physical spins
#J1_, J2_ = the coupling parameters of the J1-J2 Hamiltonian
#Marshall_sign: True = A marshall sign is applied on top of the cRNN wavefunction, False = no prior is applied
#numsamples = number of samples used for training
numsamples = 200
#num_units = number of memory units of the hidden state of the RNN
#num_layers = number of vertically stacked RNN cells

#This function trains a cRNN wavefunction for 1D J1J2 with the corresponding hyperparams
RNNEnergy, varRNNEnergy = run_J1J2(numsteps = 10, systemsize = 10, J1_  = 1.0, J2_ = 0.2, Marshall_sign = False, num_units = 10, num_layers = 1, numsamples = numsamples, learningrate = 5e-4, seed = 111)

#RNNEnergy is a numpy array of the variational energy of the cRNN wavefunction
#varRNNEnergy is a numpy array of the variance of the variational energy of the cRNN wavefunction
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# The number of variational parameters of the cRNN wavefunction is 444
#
#
# log_amplitudes[cut]: [-1.9459273-10.160663j -1.8329426-10.489491j -2.0936809 -9.455839j ...
#  -2.2411432 -8.220581j -1.9459273-10.160663j -3.304532  -9.845461j]
# slices [slice(0, 9, None), slice(9, 21, None), slice(21, 29, None), slice(29, 36, None), slice(36, 40, None), slice(40, 47, None), slice(47, 58, None), slice(58, 65, None), slice(65, 75, None), slice(75, 86, None), slice(86, 94, None), slice(94, 101, None), slice(101, 108, None), slice(108, 112, None), slice(112, 119, None), slice(119, 131, None), slice(131, 139, None), slice(139, 149, None), slice(149, 161, None), slice(161, 172, None), slice(172, 178, None), slice(178, 186, None), slice(186, 196, None), slice(196, 207, None), slice(207, 218, None), slice(218, 226, None), slice(226, 233, None), slice(233, 239, None), slice(239, 250, None), slice(250, 260, None), slice(260, 271, None), slice(271, 283, None), slice(283, 293, None), slice(293, 305, None), slice(305, 315, None), slice(315, 326, None), slice(326, 336, None), slice(336, 340, None), slice(340, 350, None), slice(350, 361, None), slice(361, 370, None), slice(370, 378, None), slice(378, 384, None), slice(384, 395, None), slice(395, 406, None), slice(406, 413, None), slice(413, 422, None), slice(422, 431, None), slice(431, 435, None), slice(435, 443, None), slice(443, 451, None), slice(451, 460, None), slice(460, 468, None), slice(468, 480, None), slice(480, 487, None), slice(487, 495, None), slice(495, 505, None), slice(505, 514, None), slice(514, 526, None), slice(526, 534, None), slice(534, 544, None), slice(544, 556, None), slice(556, 566, None), slice(566, 576, None), slice(576, 586, None), slice(586, 594, None), slice(594, 604, None), slice(604, 610, None), slice(610, 618, None), slice(618, 630, None), slice(630, 642, None), slice(642, 652, None), slice(652, 666, None), slice(666, 677, None), slice(677, 683, None), slice(683, 696, None), slice(696, 706, None), slice(706, 712, None), slice(712, 718, None), slice(718, 724, None), slice(724, 734, None), slice(734, 744, None), slice(744, 756, None), slice(756, 762, None), slice(762, 771, None), slice(771, 783, None), slice(783, 790, None), slice(790, 794, None), slice(794, 802, None), slice(802, 813, None), slice(813, 821, None), slice(821, 835, None), slice(835, 846, None), slice(846, 855, None), slice(855, 865, None), slice(865, 877, None), slice(877, 887, None), slice(887, 896, None), slice(896, 905, None), slice(905, 915, None), slice(915, 925, None), slice(925, 939, None), slice(939, 947, None), slice(947, 956, None), slice(956, 968, None), slice(968, 978, None), slice(978, 988, None), slice(988, 997, None), slice(997, 1003, None), slice(1003, 1013, None), slice(1013, 1024, None), slice(1024, 1034, None), slice(1034, 1044, None), slice(1044, 1055, None), slice(1055, 1068, None), slice(1068, 1078, None), slice(1078, 1084, None), slice(1084, 1091, None), slice(1091, 1097, None), slice(1097, 1109, None), slice(1109, 1117, None), slice(1117, 1121, None), slice(1121, 1131, None), slice(1131, 1142, None), slice(1142, 1153, None), slice(1153, 1164, None), slice(1164, 1176, None), slice(1176, 1185, None), slice(1185, 1196, None), slice(1196, 1202, None), slice(1202, 1215, None), slice(1215, 1222, None), slice(1222, 1232, None), slice(1232, 1244, None), slice(1244, 1255, None), slice(1255, 1265, None), slice(1265, 1277, None), slice(1277, 1286, None), slice(1286, 1292, None), slice(1292, 1298, None), slice(1298, 1309, None), slice(1309, 1318, None), slice(1318, 1325, None), slice(1325, 1336, None), slice(1336, 1345, None), slice(1345, 1353, None), slice(1353, 1359, None), slice(1359, 1368, None), slice(1368, 1375, None), slice(1375, 1383, None), slice(1383, 1396, None), slice(1396, 1404, None), slice(1404, 1416, None), slice(1416, 1424, None), slice(1424, 1436, None), slice(1436, 1448, None), slice(1448, 1458, None), slice(1458, 1470, None), slice(1470, 1477, None), slice(1477, 1488, None), slice(1488, 1500, None), slice(1500, 1510, None), slice(1510, 1519, None), slice(1519, 1530, None), slice(1530, 1538, None), slice(1538, 1548, None), slice(1548, 1559, None), slice(1559, 1570, None), slice(1570, 1577, None), slice(1577 ...
# [1.        +0.j         1.059627  -0.36156255j 0.657098  +0.5589063j
#  0.97506386-0.11503921j 0.942292  +0.2831112j  0.58826303-0.22966671j
#  0.72740036+0.59401226j 0.51624537-0.35102445j 0.2825866 -0.16401133j]
# [1.        +0.j         0.8173833 +0.30695063j 1.0117116 -0.27672747j
#  0.82590383+0.36661664j 0.94117707-0.10711887j 0.9750939 +0.23978387j
#  0.54728127-0.1176516j  0.3264026 +0.6519538j  1.0173279 -0.2529823j
#  1.2675354 +0.91943485j 0.49695143-0.14350504j 0.28332627-0.05555014j]
# [1.        +0.j         0.8751485 -0.65936464j 0.68669707+0.57873267j
#  0.5864047 -0.32408434j 0.42675522-1.1061566j  0.01322049+1.1125379j
#  0.4766185 -0.4713562j  0.2666526 -0.24731857j]
# [1.       +0.j         1.1309499-0.13427404j 1.1182965-0.11648474j
#  1.4894831+0.17224942j 1.1442074-0.14354056j 1.1944889-0.05698261j
#  1.1958586-0.22289632j]
# [1.        +0.j         0.5274516 -0.6109669j  0.01067964-0.8987189j
#  0.14139007-0.48911923j]
# [1.        +0.j         1.0948404 -0.12301107j 0.59919274-0.16666996j
#  1.0531366 -0.03232911j 1.1513938 +0.00249588j 0.5576214 -0.27623445j
#  0.33493406-0.10501803j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         1.0245879 -0.04984225j 0.6109179 -0.26678553j
#  0.8267704 +0.3404956j  1.0032805 +0.1818196j  0.5255845 -0.43555605j
#  0.29799107-0.20163096j]
# [1.        +0.j         0.84874505-0.8065712j  0.96196353+0.27137667j
#  0.55202657-0.17443232j 0.2592917 -1.2954494j  0.6640388 -0.9490839j
#  0.42095384+0.73277605j 1.0607035 +1.0489924j  0.49967524-0.19498351j
#  0.2570747 -0.11107918j]
# [1.        +0.j         1.044993  -0.5657776j  0.92472297+0.21296962j
#  0.91207105+0.02809881j 1.023595  +0.1575137j  0.56817895-0.13591443j
#  1.0597247 -0.57902735j 0.39432806+0.669371j   0.9471563 +0.40321994j
#  0.5235106 -0.20378134j 0.30279282-0.07499208j]
# [1.        +0.j         0.8751485 -0.65936464j 0.68669707+0.57873267j
#  0.5864047 -0.32408434j 0.42675522-1.1061566j  0.01322049+1.1125379j
#  0.4766185 -0.4713562j  0.2666526 -0.24731857j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         0.5274516 -0.6109669j  0.01067964-0.8987189j
#  0.14139007-0.48911923j]
# [1.        +0.j         1.0245879 -0.04984225j 0.6109179 -0.26678553j
#  0.8267704 +0.3404956j  1.0032805 +0.1818196j  0.5255845 -0.43555605j
#  0.29799107-0.20163096j]
# [1.        +0.j         0.7978008 +0.3289849j  1.0218515 -0.35168824j
#  1.0489122 +0.11938059j 0.5655041 -0.13338019j 0.25390846+0.6593087j
#  1.0370437 -0.36137724j 0.93761414-0.3616891j  0.8225336 +0.4831455j
#  0.99416226+0.3679195j  0.51995575-0.19458401j 0.3004751 -0.07191621j]
# [1.        +0.j         0.78889656+0.37070122j 0.97369796+0.04736665j
#  0.96827984+0.22455938j 0.60489243-0.25648704j 0.81518465+0.5123091j
#  0.5232424 -0.41170257j 0.29423502-0.19084379j]
# [1.        +0.j         0.94018227+0.08485841j 0.9145295 +0.09560632j
#  1.0121855 +0.12785114j 0.97482854-0.1747494j  1.5726056 +0.4243752j
#  0.5580829 -0.01392761j 0.6047098 +0.472701j   0.92857224+0.33971864j
#  0.9015909 -0.2694405j ]
# [1.        +0.j         0.75791883+0.38605893j 0.999192  +0.02324933j
#  0.91962206+0.25153875j 0.9605889 -0.17261757j 0.9522204 +0.25904727j
#  0.55602866-0.1266132j  0.6673011 +0.54489565j 0.8867917 -0.19318748j
#  1.1803838 +0.9287608j  0.5066118 -0.16651192j 0.29223347-0.06310392j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.       +0.j         1.0349277-0.8110232j  1.0719861-0.12008302j
#  0.954115 -1.182133j   1.1270093-0.13800435j 1.051235 -0.08818553j]
# [1.        +0.j         0.78889656+0.37070122j 0.97369796+0.04736665j
#  0.96827984+0.22455938j 0.60489243-0.25648704j 0.81518465+0.5123091j
#  0.5232424 -0.41170257j 0.29423502-0.19084379j]
# [1.        +0.j         0.8891526 -0.7612024j  0.538519  +0.60106045j
#  1.0066364 -0.3539398j  1.7881474 +0.44311476j 0.46129933-0.02229844j
#  0.34793764-1.2792945j  0.90898144-0.3887072j  2.0159705 +1.8697996j
#  0.20289199+0.01448367j]
# [1.        +0.j         0.7185445 +0.4063651j  1.0345048 -0.02429803j
#  0.83858204+0.31856853j 0.96572465-0.06597778j 0.92446727+0.235982j
#  0.9095728 -0.03366147j 1.0239364 +0.15028563j 0.5839521 -0.03442392j
#  1.6152629 +0.6633538j  0.58642834-0.03061098j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         0.8854506 +0.23877187j 0.9682703 -0.42896193j
#  1.1521623 +0.7529348j  0.5523316 -0.17453508j 0.55025035+0.61654454j
#  0.7998063 -0.74543726j 0.26026508-0.10654838j]
# [1.        +0.j         1.0245879 -0.04984225j 0.6109179 -0.26678553j
#  0.8267704 +0.3404956j  1.0032805 +0.1818196j  0.5255845 -0.43555605j
#  0.29799107-0.20163096j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         1.0722114 -0.40264583j 0.61247903+0.56760764j
#  1.0095302 -0.15786053j 0.85311115+0.33825365j 0.9331412 -0.07616345j
#  0.98609096+0.22562009j 0.5415185 -0.11203273j 1.3246317 +0.9006921j
#  0.49071792-0.13264604j 0.27726024-0.05159488j]
# [1.        +0.j         0.9897794 -0.01518898j 1.005795  -0.2302849j
#  0.8654416 +0.29541287j 0.9367467 -0.10123827j 1.6885225 +0.39858416j
#  0.5290003 +0.00329187j 0.74229777+0.37175015j 0.89438295+0.24155761j
#  0.9497952 -0.34748307j]
# [1.        +0.j         1.0685148 -0.33160946j 0.7016484 +0.5120303j
#  1.0035689 -0.32656306j 0.8062873 +0.38902965j 0.94490767-0.15447247j
#  1.5448843 +0.5630344j  0.4987851 -0.06478176j 0.11060372+0.7119924j
#  0.9564927 -0.45597607j 0.23733136-0.01185223j]
# [1.        +0.j         1.0807377 -0.36543208j 0.66146564+0.52534604j
#  1.0337127 -0.43391332j 0.9544759 +0.21038702j 0.8996797 -0.00729575j
#  1.829106  +0.34052497j 0.49740574+0.01627836j 0.02149576+0.6700763j
#  0.9844296 -0.62254524j 0.9566512 -0.5205935j  0.62809247+0.54969317j]
# [1.        +0.j         0.8700061 +0.25725707j 0.97560275-0.3376545j
#  0.86332786+0.38247046j 0.5770925 -0.21913755j 0.49928114+0.6302447j
#  0.879392  -0.5526607j  0.7067186 +1.0906978j  0.5100653 -0.30781755j
#  0.27592745-0.15025401j]
# [1.        +0.j         1.0548364 -0.5836472j  0.9058334 +0.21941668j
#  0.93181556+0.01917885j 0.98202354+0.17071323j 0.95266473-0.13076948j
#  1.664749  +0.3982256j  0.53393775-0.00426314j 1.0767792 -0.6126053j
#  0.36574316+0.6538695j  0.82660145+0.42004037j 0.8580891 -0.13628973j]
# [1.        +0.j         0.8536586 +0.26492968j 1.004946  -0.37449935j
#  0.78842044+0.40434083j 0.94948834-0.17284748j 1.5144519 +0.57507807j
#  0.5042867 -0.06887262j 0.46331617+0.62298656j 0.9128791 -0.62348217j
#  0.24252981-0.01404646j]
# [1.        +0.j         1.0937439 -0.50134295j 0.49435616+0.59472334j
#  1.0717174 -0.3503908j  1.0839325 -0.01320951j 1.0311704 -0.02949826j
#  1.6852795 +0.11707518j 1.0451765 -0.4208008j  1.0322868 +0.16902195j
#  1.0432067 +0.16136275j 0.96485287+0.06470915j]
# [1.        +0.j         0.84530973+0.28843388j 0.98004746-0.22728848j
#  0.9153615 +0.31680512j 0.5939756 -0.24167995j 0.3942438 +0.6619782j
#  0.965036  -0.17488873j 0.66908854+0.62360543j 0.5169381 -0.37497246j
#  0.286907  -0.17475429j]
# [1.        +0.j         0.5274516 -0.6109669j  0.01067964-0.8987189j
#  0.14139007-0.48911923j]
# [1.        +0.j         0.92269415-0.6494658j  0.6191038 +0.58834076j
#  0.96949375-0.19690038j 0.9088319 +0.34038562j 0.5634349 -0.1945016j
#  0.77229524-0.9748715j  0.8742808 +1.0884346j  0.5043874 -0.2521686j
#  0.26545987-0.12874506j]
# [1.        +0.j         1.065234  -0.30238736j 0.7300476 +0.49647808j
#  1.0060441 -0.48541135j 1.678477  +0.5061307j  0.47838145-0.03677509j
#  0.19795561+0.7278417j  0.85111725-0.8156806j  0.8756361 -0.614075j
#  1.6220291 +1.8480908j  0.21808894+0.00714166j]
# [1.        +0.j         1.052811  -0.28390253j 0.7543482 +0.49288744j
#  0.96783674-0.40114868j 1.1901642 +0.7421682j  0.5461209 -0.16467817j
#  0.24595077+0.7534937j  0.8247526 -0.6735124j  0.255198  -0.09886262j]
# [1.        +0.j         0.8751485 -0.65936464j 0.68669707+0.57873267j
#  0.5864047 -0.32408434j 0.42675522-1.1061566j  0.01322049+1.1125379j
#  0.4766185 -0.4713562j  0.2666526 -0.24731857j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.7558427 +0.37685445j 0.9996907 +0.02913303j
#  0.92104256+0.24127592j 1.0292841 -0.33556604j 1.8450211 +0.32499132j
#  0.4960463 +0.02793758j 0.6929496 +0.5136048j  0.9567573 -0.53895664j
#  0.9289571 -0.40244606j 2.39224   +1.5516309j ]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         1.0102917 -0.03832188j 0.9840092 -0.28324032j
#  1.3747175 +0.60033387j 0.5306995 -0.09829149j 0.7918293 +0.35111868j
#  0.960366  +0.19926631j 0.89885026-0.47387746j 0.26818123-0.03563221j]
# [1.        +0.j         0.9531938 +0.07756773j 0.9019887 +0.10134317j
#  1.0382913 +0.11893716j 0.5927242 -0.15994948j 0.63108706+0.47471815j
#  1.0000328 +0.33024663j 0.5498534 -0.25950152j 0.32856148-0.09752029j]
# [1.        +0.j         0.5274516 -0.6109669j  0.01067964-0.8987189j
#  0.14139007-0.48911923j]
# [1.        +0.j         0.8854506 +0.23877187j 0.9682703 -0.42896193j
#  1.1521623 +0.7529348j  0.5523316 -0.17453508j 0.55025035+0.61654454j
#  0.7998063 -0.74543726j 0.26026508-0.10654838j]
# [1.        +0.j         0.8854506 +0.23877187j 0.9682703 -0.42896193j
#  1.1521623 +0.7529348j  0.5523316 -0.17453508j 0.55025035+0.61654454j
#  0.7998063 -0.74543726j 0.26026508-0.10654838j]
# [1.        +0.j         0.639754  +0.46911517j 1.0838184 -0.19053413j
#  1.1350292 -0.05991494j 0.6363896 -0.06239844j 1.058027  -0.17238916j
#  1.134231  +0.08197188j 1.208367  +0.04947776j 0.68649185-0.12257927j]
# [1.        +0.j         0.9185339 -0.5719118j  0.7288977 +0.54917467j
#  0.5977567 -0.35484418j 0.80743545-0.829779j   0.1827066 +0.7989534j
#  0.44856614-0.55844176j 0.2678313 -0.2814175j ]
# [1.        +0.j         0.8748657 +0.16360171j 0.9971725 -0.00195997j
#  1.0586214 +0.0315668j  1.0401884 -0.04883036j 0.9070743 +0.07767969j
#  0.46786028+0.5072907j  0.8826117 +0.09430037j 0.9589075 +0.24529353j
#  0.99779373+0.2104101j  0.99361265+0.01765817j 1.3798686 +0.2618619j ]
# [1.        +0.j         1.0245879 -0.04984225j 0.6109179 -0.26678553j
#  0.8267704 +0.3404956j  1.0032805 +0.1818196j  0.5255845 -0.43555605j
#  0.29799107-0.20163096j]
# [1.        +0.j         0.9596903 +0.05867342j 0.9480283 +0.04006235j
#  1.0198176 -0.02186292j 0.7978889 +0.23645206j 0.86708313+0.14558327j
#  0.996153  +0.10971963j 0.96395266+0.03985951j]
# [1.        +0.j         0.8700061 +0.25725707j 0.97560275-0.3376545j
#  0.86332786+0.38247046j 0.5770925 -0.21913755j 0.49928114+0.6302447j
#  0.879392  -0.5526607j  0.7067186 +1.0906978j  0.5100653 -0.30781755j
#  0.27592745-0.15025401j]
# [1.        +0.j         1.052811  -0.28390253j 0.7543482 +0.49288744j
#  0.96783674-0.40114868j 1.1901642 +0.7421682j  0.5461209 -0.16467817j
#  0.24595077+0.7534937j  0.8247526 -0.6735124j  0.255198  -0.09886262j]
# [1.        +0.j         0.98247576-0.00132674j 1.0255861 -0.2891012j
#  1.0551996 +0.11403999j 0.5702714 -0.02695764j 0.72451794+0.3837702j
#  0.86742187+0.27029788j 0.97047937-0.43390915j 0.92623556-0.3245552j
#  0.8795248 +0.41041452j 1.7362739 +0.613145j   0.5611568 -0.00341597j]
# [1.        +0.j         0.78889656+0.37070122j 0.97369796+0.04736665j
#  0.96827984+0.22455938j 0.60489243-0.25648704j 0.81518465+0.5123091j
#  0.5232424 -0.41170257j 0.29423502-0.19084379j]
# [1.        +0.j         0.92269415-0.6494658j  0.6191038 +0.58834076j
#  0.96949375-0.19690038j 0.9088319 +0.34038562j 0.5634349 -0.1945016j
#  0.77229524-0.9748715j  0.8742808 +1.0884346j  0.5043874 -0.2521686j
#  0.26545987-0.12874506j]
# [1.        +0.j         0.9195425 -0.7155094j  0.53523546+0.6111053j
#  1.0154886 -0.30451825j 1.0479285 +0.13829257j 0.52098185-0.09163723j
#  0.7316712 -1.0913627j  0.9273096 -0.2951059j  0.82119054+0.500721j
#  1.5861456 +0.79299384j 0.46571678-0.07729086j 0.25701147-0.03572707j]
# [1.        +0.j         0.9897794 -0.01518898j 1.005795  -0.2302849j
#  0.8654416 +0.29541287j 0.9367467 -0.10123827j 1.6885225 +0.39858416j
#  0.5290003 +0.00329187j 0.74229777+0.37175015j 0.89438295+0.24155761j
#  0.9497952 -0.34748307j]
# [1.        +0.j         0.93179816-0.773621j   0.4698892 +0.60529155j
#  1.0601265 -0.41800994j 1.0381571 +0.04641339j 0.9319036 +0.09852426j
#  1.890327  +0.0346727j  0.72123444-1.204315j   1.0218412 -0.5401904j
#  0.9388659 +0.26683658j]
# [1.       +0.j         0.7073829+0.4027184j  1.0444757-0.02928374j
#  0.8213945+0.3179291j  0.9835061-0.07648921j 0.8904869+0.24277657j
#  0.9490146-0.05409725j 0.9396864+0.18576458j 1.003842 +0.00675604j
#  1.7065388+0.10060029j]
# [1.        +0.j         0.9185339 -0.5719118j  0.7288977 +0.54917467j
#  0.5977567 -0.35484418j 0.80743545-0.829779j   0.1827066 +0.7989534j
#  0.44856614-0.55844176j 0.2678313 -0.2814175j ]
# [1.        +0.j         0.8700061 +0.25725707j 0.97560275-0.3376545j
#  0.86332786+0.38247046j 0.5770925 -0.21913755j 0.49928114+0.6302447j
#  0.879392  -0.5526607j  0.7067186 +1.0906978j  0.5100653 -0.30781755j
#  0.27592745-0.15025401j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.78889656+0.37070122j 0.97369796+0.04736665j
#  0.96827984+0.22455938j 0.60489243-0.25648704j 0.81518465+0.5123091j
#  0.5232424 -0.41170257j 0.29423502-0.19084379j]
# [1.        +0.j         0.84202397+0.27805397j 1.0114863 -0.44899625j
#  1.0194159 +0.18557726j 0.5338313 -0.10331932j 0.42380953+0.63215536j
#  0.8990829 -0.7341608j  0.90389186-0.5309343j  0.7286918 +0.55850434j
#  1.4371346 +0.86729145j 0.48123795-0.10194533j 0.26990858-0.04369395j]
# [1.        +0.j         0.8748657 +0.16360171j 0.9971725 -0.00195997j
#  1.0586214 +0.0315668j  1.0401884 -0.04883036j 0.9070743 +0.07767969j
#  0.46786028+0.5072907j  0.8826117 +0.09430037j 0.9589075 +0.24529353j
#  0.99779373+0.2104101j  0.99361265+0.01765817j 1.3798686 +0.2618619j ]
# [1.        +0.j         0.9994605 -0.02912632j 1.0348979 -0.3532557j
#  1.8218117 +0.33741993j 0.5005987 +0.02557453j 0.76641136+0.35463625j
#  0.9275731 +0.21431918j 0.95954585-0.59362423j 0.93367416-0.43568236j
#  2.3019118 +1.5575523j ]
# [1.        +0.j         1.058176  -0.56233686j 0.9335077 +0.18080412j
#  1.0109454 -0.22999536j 1.0708148 +0.09106119j 0.5578179 -0.02238961j
#  1.0778215 -0.5709117j  0.44082597+0.6367827j  0.6655331 +0.49616346j
#  0.9591787 -0.21817294j 0.908845  -0.22703561j 0.927313  +0.3734657j
#  1.8258438 +0.56520075j 0.5420922 +0.00662749j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         0.8514698 -0.7175994j  0.80961335+0.9378054j
#  0.57316995-0.26340112j 0.2720029 -1.1894351j  0.26828158-0.18665399j]
# [1.        +0.j         0.7979942 +0.31536224j 1.0319579 -0.3230986j
#  0.7581788 +0.4045371j  0.99833566-0.19231033j 1.0796151 +0.07501459j
#  0.5562698 -0.02012269j 0.28528357+0.6380112j  1.050807  -0.32744265j
#  0.89254165-0.15913242j 0.951221  +0.35977358j 1.8573846 +0.5363583j
#  0.5374408 +0.01527791j]
# [1.        +0.j         0.92269415-0.6494658j  0.6191038 +0.58834076j
#  0.96949375-0.19690038j 0.9088319 +0.34038562j 0.5634349 -0.1945016j
#  0.77229524-0.9748715j  0.8742808 +1.0884346j  0.5043874 -0.2521686j
#  0.26545987-0.12874506j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.8514698 -0.7175994j  0.80961335+0.9378054j
#  0.57316995-0.26340112j 0.2720029 -1.1894351j  0.26828158-0.18665399j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.8830133 -0.7510626j  0.99060565+0.20118812j
#  0.57972467-0.21444768j 0.6641089 -1.115111j   0.774593  -0.8339153j
#  0.49492055+0.70737j    0.8318125 +0.5200342j  0.51374   -0.3182217j
#  0.2761194 -0.15009335j]
# [1.        +0.j         1.0490464 -0.7362084j  0.95131344+0.12076515j
#  0.9499807 +0.00977669j 1.0196242 -0.02197746j 1.0346099 -0.9775115j
#  0.73197204+0.3848644j  0.8741962 +0.10704692j 0.993581  +0.12127632j
#  0.9629782 +0.03308618j]
# [1.        +0.j         0.82833   +0.2958476j  1.0006275 -0.24752359j
#  0.8737398 +0.32560456j 0.967063  -0.237809j   1.4444364 +0.58772j
#  0.5171255 -0.08380051j 0.35932404+0.6499626j  0.9982912 -0.20713542j
#  0.55721915+0.610002j   0.88470364-0.32741106j 0.25497714-0.02482786j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         1.0102917 -0.03832188j 0.9840092 -0.28324032j
#  1.3747175 +0.60033387j 0.5306995 -0.09829149j 0.7918293 +0.35111868j
#  0.960366  +0.19926631j 0.89885026-0.47387746j 0.26818123-0.03563221j]
# [1.        +0.j         0.8173833 +0.30695063j 1.0117116 -0.27672747j
#  0.82590383+0.36661664j 0.94117707-0.10711887j 0.9750939 +0.23978387j
#  0.54728127-0.1176516j  0.3264026 +0.6519538j  1.0173279 -0.2529823j
#  1.2675354 +0.91943485j 0.49695143-0.14350504j 0.28332627-0.05555014j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         0.5274516 -0.6109669j  0.01067964-0.8987189j
#  0.14139007-0.48911923j]
# [1.        +0.j         0.8751485 -0.65936464j 0.68669707+0.57873267j
#  0.5864047 -0.32408434j 0.42675522-1.1061566j  0.01322049+1.1125379j
#  0.4766185 -0.4713562j  0.2666526 -0.24731857j]
# [1.        +0.j         0.8418652 +0.26735368j 1.0244465 -0.41111895j
#  0.73048913+0.42517132j 1.0025601 -0.24058329j 1.9466884 +0.26586765j
#  0.4758644 +0.03713675j 0.44047529+0.6132331j  0.93142253-0.6903577j
#  0.9030473 -0.23356044j 2.7952712 +1.5221417j ]
# [1.        +0.j         0.8854506 +0.23877187j 0.9682703 -0.42896193j
#  1.1521623 +0.7529348j  0.5523316 -0.17453508j 0.55025035+0.61654454j
#  0.7998063 -0.74543726j 0.26026508-0.10654838j]
# [1.        +0.j         0.7753849 +0.32901323j 1.0543664 -0.38479674j
#  0.974751  +0.15194884j 1.0161444 -0.18050687j 1.8805503 +0.00619633j
#  0.22428319+0.6265105j  1.0873874 -0.41740158j 0.9977428 -0.4324547j
#  0.6941093 +0.48051608j 0.77459127+0.41545478j 0.94419235-0.17372878j
#  1.0125606 -0.15957814j 3.1477463 +0.75338686j]
# [1.        +0.0000000e+00j 0.845824  -9.1222978e-01j
#  1.0501583 +3.7623748e-02j 0.939011  -9.6847728e-02j
#  1.735055  +3.7421522e-01j 0.51651686+6.9061003e-04j
#  0.4983357 -1.3719857e+00j 0.6515846 -1.1648921e+00j
#  0.9075183 +3.2759038e-01j 0.9648183 +2.8357446e-01j
#  0.82373   -2.9196931e-02j]
# [1.        +0.j         1.059627  -0.36156255j 0.657098  +0.5589063j
#  0.97506386-0.11503921j 0.942292  +0.2831112j  0.58826303-0.22966671j
#  0.72740036+0.59401226j 0.51624537-0.35102445j 0.2825866 -0.16401133j]
# [1.        +0.j         0.8830133 -0.7510626j  0.99060565+0.20118812j
#  0.57972467-0.21444768j 0.6641089 -1.115111j   0.774593  -0.8339153j
#  0.49492055+0.70737j    0.8318125 +0.5200342j  0.51374   -0.3182217j
#  0.2761194 -0.15009335j]
# [1.        +0.j         1.0790169 -0.3426667j  0.6854148 +0.5107526j
#  1.0237867 -0.3611157j  0.74862045+0.4108989j  0.999151  -0.22023438j
#  1.9716132 +0.25607136j 0.4709607 +0.03740574j 0.08760443+0.6874053j
#  0.98183495-0.5146765j  0.897309  -0.20542994j 2.901738  +1.5056868j ]
# [1.        +0.j         0.8830133 -0.7510626j  0.99060565+0.20118812j
#  0.57972467-0.21444768j 0.6641089 -1.115111j   0.774593  -0.8339153j
#  0.49492055+0.70737j    0.8318125 +0.5200342j  0.51374   -0.3182217j
#  0.2761194 -0.15009335j]
# [1.        +0.j         1.0125189 -0.00670725j 0.8719219 +0.10352048j
#  1.0473999 +0.07396968j 1.1041596 -0.10411888j 1.5128174 +0.16401489j
#  0.89433366+0.15515043j 1.0114334 +0.2297361j  1.1582179 -0.18308824j]
# [1.       +0.j         0.6815486+0.413368j   1.0729096-0.08196528j
#  0.7504275+0.37238777j 1.0455282-0.20433114j 1.0386022-0.06035685j
#  1.0020034-0.22312072j 1.04663  +0.05218123j 0.9921852-0.01374948j]
# [1.        +0.j         0.8700061 +0.25725707j 0.97560275-0.3376545j
#  0.86332786+0.38247046j 0.5770925 -0.21913755j 0.49928114+0.6302447j
#  0.879392  -0.5526607j  0.7067186 +1.0906978j  0.5100653 -0.30781755j
#  0.27592745-0.15025401j]
# [1.        +0.j         0.92902404-0.6070198j  0.68587977+0.5507169j
#  0.96495587-0.36140576j 1.2370089 +0.73432124j 0.5379605 -0.15144181j
#  0.8057523 -0.90282935j 0.08893169+0.73837376j 0.86435765-0.54038084j
#  0.24869958-0.08835765j]
# [1.        +0.j         1.058176  -0.56233686j 0.9335077 +0.18080412j
#  1.0109454 -0.22999536j 1.0708148 +0.09106119j 0.5578179 -0.02238961j
#  1.0778215 -0.5709117j  0.44082597+0.6367827j  0.6655331 +0.49616346j
#  0.9591787 -0.21817294j 0.908845  -0.22703561j 0.927313  +0.3734657j
#  1.8258438 +0.56520075j 0.5420922 +0.00662749j]
# [1.        +0.j         0.8854506 +0.23877187j 0.9682703 -0.42896193j
#  1.1521623 +0.7529348j  0.5523316 -0.17453508j 0.55025035+0.61654454j
#  0.7998063 -0.74543726j 0.26026508-0.10654838j]
# [1.        +0.j         0.9531938 +0.07756773j 0.9019887 +0.10134317j
#  1.0382913 +0.11893716j 0.5927242 -0.15994948j 0.63108706+0.47471815j
#  1.0000328 +0.33024663j 0.5498534 -0.25950152j 0.32856148-0.09752029j]
# [1.        +0.j         0.97304577+0.01155839j 0.97244614-0.1228316j
#  0.9447147 +0.21630006j 0.96098626-0.152459j   1.6158459 +0.4160092j
#  0.54669577-0.00773191j 0.7016042 +0.39915925j 0.82751626+0.3073917j
#  0.9010742 -0.01936114j 0.7536975 +0.4662759j  0.8746823 -0.19523887j]
# [1.        +0.j         0.8700061 +0.25725707j 0.97560275-0.3376545j
#  0.86332786+0.38247046j 0.5770925 -0.21913755j 0.49928114+0.6302447j
#  0.879392  -0.5526607j  0.7067186 +1.0906978j  0.5100653 -0.30781755j
#  0.27592745-0.15025401j]
# [1.        +0.j         0.76947314+0.37672916j 0.988391  +0.03749115j
#  0.9417464 +0.23295829j 0.97781044-0.26600894j 1.4012504 +0.5941594j
#  0.5256886 -0.09259743j 0.7469891 +0.51018184j 0.893356  -0.42431247j
#  0.26335284-0.03124615j]
# [1.        +0.j         1.059627  -0.36156255j 0.657098  +0.5589063j
#  0.97506386-0.11503921j 0.942292  +0.2831112j  0.58826303-0.22966671j
#  0.72740036+0.59401226j 0.51624537-0.35102445j 0.2825866 -0.16401133j]
# [1.        +0.j         0.8514698 -0.7175994j  0.80961335+0.9378054j
#  0.57316995-0.26340112j 0.2720029 -1.1894351j  0.26828158-0.18665399j]
# [1.        +0.j         1.0199887 -0.03651073j 1.0090967 -0.13309264j
#  0.9862343 +0.0195584j  0.91350675+0.10026753j 0.904627  +0.20807248j
#  0.9263718 -0.03749936j 0.99182945-0.10924342j 0.9114922 +0.20019983j
#  0.90721506+0.08749802j]
# [1.        +0.j         0.72580963+0.4015947j  1.027556  -0.0122059j
#  0.8540713 +0.30576158j 0.94977844-0.045159j   0.96663946+0.19379076j
#  0.95602834-0.1403186j  1.6373178 +0.40753356j 0.5413992 -0.00511222j
#  0.793424  +0.4469484j  0.864854  -0.1598113j ]
# [1.        +0.j         0.8830133 -0.7510626j  0.99060565+0.20118812j
#  0.57972467-0.21444768j 0.6641089 -1.115111j   0.774593  -0.8339153j
#  0.49492055+0.70737j    0.8318125 +0.5200342j  0.51374   -0.3182217j
#  0.2761194 -0.15009335j]
# [1.       +0.j         0.7073829+0.4027184j  1.0444757-0.02928374j
#  0.8213945+0.3179291j  0.9835061-0.07648921j 0.8904869+0.24277657j
#  0.9490146-0.05409725j 0.9396864+0.18576458j 1.003842 +0.00675604j
#  1.7065388+0.10060029j]
# [1.        +0.j         0.7499548 +0.34775892j 1.06539   -0.4902632j
#  1.0276796 +0.06033869j 0.9407746 +0.0824314j  0.96363   +0.03180857j
#  0.15838334+0.6142124j  1.1008465 -0.5893457j  1.0162766 -0.6669257j
#  0.9086927 +0.29158428j 1.6002492 +0.16969347j]
# [1.        +0.j         1.0714996 -0.558842j   0.9345868 +0.16444825j
#  1.0164785 -0.19804405j 0.8306988 +0.29554984j 0.99478453-0.13742019j
#  1.933027  -0.0238171j  1.0980676 -0.5583241j  0.45508087+0.6163638j
#  0.68896574+0.45562634j 0.9657456 -0.17933089j 0.97169334-0.08272532j
#  3.3675294 +0.6933138j ]
# [1.        +0.j         0.8700061 +0.25725707j 0.97560275-0.3376545j
#  0.86332786+0.38247046j 0.5770925 -0.21913755j 0.49928114+0.6302447j
#  0.879392  -0.5526607j  0.7067186 +1.0906978j  0.5100653 -0.30781755j
#  0.27592745-0.15025401j]
# [1.        +0.j         0.8514698 -0.7175994j  0.80961335+0.9378054j
#  0.57316995-0.26340112j 0.2720029 -1.1894351j  0.26828158-0.18665399j]
# [1.        +0.j         1.0245879 -0.04984225j 0.6109179 -0.26678553j
#  0.8267704 +0.3404956j  1.0032805 +0.1818196j  0.5255845 -0.43555605j
#  0.29799107-0.20163096j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.84202397+0.27805397j 1.0114863 -0.44899625j
#  1.0194159 +0.18557726j 0.5338313 -0.10331932j 0.42380953+0.63215536j
#  0.8990829 -0.7341608j  0.90389186-0.5309343j  0.7286918 +0.55850434j
#  1.4371346 +0.86729145j 0.48123795-0.10194533j 0.26990858-0.04369395j]
# [1.        +0.j         0.78889656+0.37070122j 0.97369796+0.04736665j
#  0.96827984+0.22455938j 0.60489243-0.25648704j 0.81518465+0.5123091j
#  0.5232424 -0.41170257j 0.29423502-0.19084379j]
# [1.        +0.j         0.5274516 -0.6109669j  0.01067964-0.8987189j
#  0.14139007-0.48911923j]
# [1.        +0.j         0.7459697 +0.37178978j 1.0087223 +0.02412945j
#  0.9047934 +0.24411657j 1.0690738 -0.40263832j 2.0095663 -0.11317979j
#  0.65489936+0.50770223j 1.0018153 -0.65451586j 1.0076361 -0.5606163j
#  3.7444754 +0.44427255j]
# [1.        +0.j         1.0722114 -0.40264583j 0.61247903+0.56760764j
#  1.0095302 -0.15786053j 0.85311115+0.33825365j 0.9331412 -0.07616345j
#  0.98609096+0.22562009j 0.5415185 -0.11203273j 1.3246317 +0.9006921j
#  0.49071792-0.13264604j 0.27726024-0.05159488j]
# [1.        +0.j         0.744024  +0.38700658j 1.0100882 +0.01550064j
#  0.8996614 +0.257858j   0.99453956-0.19938415j 0.87820596+0.2863117j
#  0.9310408 -0.08745929j 1.7098118 +0.389341j   0.52423316+0.00588263j
#  0.61892986+0.5400836j  0.9355883 -0.2342832j ]
# [1.        +0.j         0.8050841 +0.30946648j 1.0271498 -0.2943983j
#  0.79473335+0.37253478j 0.9744797 -0.13057542j 0.8998844 +0.27071607j
#  0.92180574-0.06404956j 1.7465012 +0.37545347j 0.5156863 +0.00935746j
#  0.30518633+0.63862574j 1.0420754 -0.2814468j ]
# [1.        +0.j         0.96611315+0.02269167j 0.9870947 -0.1448331j
#  0.9032767 +0.25462353j 0.9192862 -0.05732173j 1.0150495 +0.16103604j
#  0.5894854 -0.03744006j 0.6849742 +0.40889964j 0.8029364 +0.3268021j
#  0.92551845-0.04890504j 1.5731711 +0.6824793j  0.5956468 -0.03859286j]
# [1.        +0.j         0.8261082 -1.0079786j  1.0530025 +0.00366643j
#  0.92107755+0.1033278j  0.9767892 +0.02115949j 0.39365336-1.5265923j
#  0.52190685-1.3900377j  0.99710554+0.1597767j  1.6749684 +0.1457287j ]
# [1.        +0.j         0.62147963+0.46363184j 1.1044115 -0.20652726j
#  1.0822902 -0.02560422j 1.0299807 -0.03630485j 0.9141026 +0.07232655j
#  1.100884  -0.2081079j  1.0362287 +0.13106883j 1.0447329 +0.14222193j
#  0.96467227+0.0578949j  1.4116728 +0.25206682j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.8958121 -0.8062057j  0.9202011 +0.23173986j
#  1.0124515 -0.25857893j 1.9465477 +0.28145874j 0.47494474+0.03155481j
#  0.6504269 -1.225427j   0.787408  -0.9457724j  0.38254902+0.6674273j
#  0.62193125+0.54028445j 0.9540482 -0.28040898j 0.91246814-0.2763779j
#  2.7955813 +1.5196259j ]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         0.84530973+0.28843388j 0.98004746-0.22728848j
#  0.9153615 +0.31680512j 0.5939756 -0.24167995j 0.3942438 +0.6619782j
#  0.965036  -0.17488873j 0.66908854+0.62360543j 0.5169381 -0.37497246j
#  0.286907  -0.17475429j]
# [1.        +0.j         1.0813524 -0.3947646j  0.6167607 +0.55506724j
#  1.0106094 -0.14625086j 0.8686879 +0.3064084j  1.0167958 -0.2871918j
#  1.9100125 +0.29582787j 0.48260164+0.03123892j 0.5244148 +0.58632654j
#  0.9546636 -0.37712437j 0.9171744 -0.3195654j  2.6470592 +1.5363351j ]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         0.84530973+0.28843388j 0.98004746-0.22728848j
#  0.9153615 +0.31680512j 0.5939756 -0.24167995j 0.3942438 +0.6619782j
#  0.965036  -0.17488873j 0.66908854+0.62360543j 0.5169381 -0.37497246j
#  0.286907  -0.17475429j]
# [1.        +0.j         0.76815265+0.3351903j  1.0588148 -0.409825j
#  0.9329368 +0.1957021j  0.93020844-0.00572729j 0.95400774+0.16946898j
#  0.99303424+0.01935882j 1.7386827 +0.0915922j  0.20538552+0.6242056j
#  1.0939051 -0.4590583j  1.0100037 -0.4840533j  0.60626435+0.5190121j ]
# [1.        +0.j         1.0102917 -0.03832188j 0.9840092 -0.28324032j
#  1.3747175 +0.60033387j 0.5306995 -0.09829149j 0.7918293 +0.35111868j
#  0.960366  +0.19926631j 0.89885026-0.47387746j 0.26818123-0.03563221j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         1.0483088 -0.51324534j 0.9875479 +0.12936331j
#  0.9748282 -0.24869862j 1.4351249 +0.5815956j  0.51887083-0.08753364j
#  1.0553813 -0.46798483j 0.5531305 +0.63345546j 0.8518873 +0.4061089j
#  0.893804  -0.380507j   0.2564116 -0.02858388j]
# [1.        +0.j         1.059627  -0.36156255j 0.657098  +0.5589063j
#  0.97506386-0.11503921j 0.942292  +0.2831112j  0.58826303-0.22966671j
#  0.72740036+0.59401226j 0.51624537-0.35102445j 0.2825866 -0.16401133j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         1.0483088 -0.51324534j 0.9875479 +0.12936331j
#  0.9748282 -0.24869862j 1.4351249 +0.5815956j  0.51887083-0.08753364j
#  1.0553813 -0.46798483j 0.5531305 +0.63345546j 0.8518873 +0.4061089j
#  0.893804  -0.380507j   0.2564116 -0.02858388j]
# [1.        +0.j         1.0236404 -0.6470945j  1.0953662 -0.03374571j
#  0.5788777 -0.14474304j 1.0119605 -0.76121986j 1.0200971 +0.20207427j
#  1.1265265 +0.13799322j 0.53755236-0.22852033j 0.31294712-0.08484712j]
# [1.        +0.j         0.8751485 -0.65936464j 0.68669707+0.57873267j
#  0.5864047 -0.32408434j 0.42675522-1.1061566j  0.01322049+1.1125379j
#  0.4766185 -0.4713562j  0.2666526 -0.24731857j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         1.0383261 -0.4879078j  1.0114943 +0.11933731j
#  0.5985081 -0.2425501j  1.0341268 -0.4258928j  0.5979525 +0.64374673j
#  0.9193373 +0.39881596j 0.5231207 -0.3852928j  0.28931713-0.17824177j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         0.78889656+0.37070122j 0.97369796+0.04736665j
#  0.96827984+0.22455938j 0.60489243-0.25648704j 0.81518465+0.5123091j
#  0.5232424 -0.41170257j 0.29423502-0.19084379j]
# [1.        +0.j         0.7979942 +0.31536224j 1.0319579 -0.3230986j
#  0.7581788 +0.4045371j  0.99833566-0.19231033j 1.0796151 +0.07501459j
#  0.5562698 -0.02012269j 0.28528357+0.6380112j  1.050807  -0.32744265j
#  0.89254165-0.15913242j 0.951221  +0.35977358j 1.8573846 +0.5363583j
#  0.5374408 +0.01527791j]
# [1.        +0.j         0.82686716-0.92289615j 1.8998864 +0.34001675j
#  0.4460771 -0.00449974j 0.03270039-1.4500087j  0.5057049 -1.221682j
#  2.5116537 +1.7474556j  0.18948628+0.02391686j]
# [1.        +0.j         0.82833   +0.2958476j  1.0006275 -0.24752359j
#  0.8737398 +0.32560456j 0.967063  -0.237809j   1.4444364 +0.58772j
#  0.5171255 -0.08380051j 0.35932404+0.6499626j  0.9982912 -0.20713542j
#  0.55721915+0.610002j   0.88470364-0.32741106j 0.25497714-0.02482786j]
# [1.        +0.j         1.0816373 -0.11307602j 0.9828129 -0.18763418j
#  1.549059  +0.43088242j 0.564083  -0.01836192j 1.0265317 -0.01452605j
#  1.1092744 +0.02383468j 0.91712475-0.30660558j]
# [1.        +0.j         0.7978008 +0.3289849j  1.0218515 -0.35168824j
#  1.0489122 +0.11938059j 0.5655041 -0.13338019j 0.25390846+0.6593087j
#  1.0370437 -0.36137724j 0.93761414-0.3616891j  0.8225336 +0.4831455j
#  0.99416226+0.3679195j  0.51995575-0.19458401j 0.3004751 -0.07191621j]
# [1.        +0.j         0.7978008 +0.3289849j  1.0218515 -0.35168824j
#  1.0489122 +0.11938059j 0.5655041 -0.13338019j 0.25390846+0.6593087j
#  1.0370437 -0.36137724j 0.93761414-0.3616891j  0.8225336 +0.4831455j
#  0.99416226+0.3679195j  0.51995575-0.19458401j 0.3004751 -0.07191621j]
# [1.        +0.j         0.9019374 +0.11920501j 0.96322787+0.05441074j
#  0.91190624+0.20451841j 0.9437856 -0.02814254j 0.9476248 +0.17050157j
#  0.99822515+0.00081775j 0.9304737 +0.06232859j 0.52996945+0.48032266j
#  1.4583191 +0.23339225j]
# [1.        +0.j         1.0807377 -0.36543208j 0.66146564+0.52534604j
#  1.0337127 -0.43391332j 0.9544759 +0.21038702j 0.8996797 -0.00729575j
#  1.829106  +0.34052497j 0.49740574+0.01627836j 0.02149576+0.6700763j
#  0.9844296 -0.62254524j 0.9566512 -0.5205935j  0.62809247+0.54969317j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# [1.        +0.j         1.0685148 -0.33160946j 0.7016484 +0.5120303j
#  1.0035689 -0.32656306j 0.8062873 +0.38902965j 0.94490767-0.15447247j
#  1.5448843 +0.5630344j  0.4987851 -0.06478176j 0.11060372+0.7119924j
#  0.9564927 -0.45597607j 0.23733136-0.01185223j]
# [1.        +0.j         0.84202397+0.27805397j 1.0114863 -0.44899625j
#  1.0194159 +0.18557726j 0.5338313 -0.10331932j 0.42380953+0.63215536j
#  0.8990829 -0.7341608j  0.90389186-0.5309343j  0.7286918 +0.55850434j
#  1.4371346 +0.86729145j 0.48123795-0.10194533j 0.26990858-0.04369395j]
# [1.        +0.j         0.92269415-0.6494658j  0.6191038 +0.58834076j
#  0.96949375-0.19690038j 0.9088319 +0.34038562j 0.5634349 -0.1945016j
#  0.77229524-0.9748715j  0.8742808 +1.0884346j  0.5043874 -0.2521686j
#  0.26545987-0.12874506j]
# [1.        +0.j         1.0383261 -0.4879078j  1.0114943 +0.11933731j
#  0.5985081 -0.2425501j  1.0341268 -0.4258928j  0.5979525 +0.64374673j
#  0.9193373 +0.39881596j 0.5231207 -0.3852928j  0.28931713-0.17824177j]
# [1.        +0.j         0.7499548 +0.34775892j 1.06539   -0.4902632j
#  1.0276796 +0.06033869j 0.9407746 +0.0824314j  0.96363   +0.03180857j
#  0.15838334+0.6142124j  1.1008465 -0.5893457j  1.0162766 -0.6669257j
#  0.9086927 +0.29158428j 1.6002492 +0.16969347j]
# [1.        +0.j         0.78889656+0.37070122j 0.97369796+0.04736665j
#  0.96827984+0.22455938j 0.60489243-0.25648704j 0.81518465+0.5123091j
#  0.5232424 -0.41170257j 0.29423502-0.19084379j]
# [1.        +0.j         0.6979822 +0.4412296j  1.042203  -0.084811j
#  1.0746233 +0.03945255j 0.58644485-0.15272155j 0.94865036+0.0291216j
#  0.9283867 +0.35812956j 1.0765681 +0.23453024j 0.54401076-0.24372046j
#  0.32168728-0.09102353j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         1.0722114 -0.40264583j 0.61247903+0.56760764j
#  1.0095302 -0.15786053j 0.85311115+0.33825365j 0.9331412 -0.07616345j
#  0.98609096+0.22562009j 0.5415185 -0.11203273j 1.3246317 +0.9006921j
#  0.49071792-0.13264604j 0.27726024-0.05159488j]
# [1.        +0.j         1.0948404 -0.12301107j 0.59919274-0.16666996j
#  1.0531366 -0.03232911j 1.1513938 +0.00249588j 0.5576214 -0.27623445j
#  0.33493406-0.10501803j]
# [1.        +0.j         1.0483088 -0.51324534j 0.9875479 +0.12936331j
#  0.9748282 -0.24869862j 1.4351249 +0.5815956j  0.51887083-0.08753364j
#  1.0553813 -0.46798483j 0.5531305 +0.63345546j 0.8518873 +0.4061089j
#  0.893804  -0.380507j   0.2564116 -0.02858388j]
# [1.        +0.j         0.5274516 -0.6109669j  0.01067964-0.8987189j
#  0.14139007-0.48911923j]
# [1.        +0.j         0.8700061 +0.25725707j 0.97560275-0.3376545j
#  0.86332786+0.38247046j 0.5770925 -0.21913755j 0.49928114+0.6302447j
#  0.879392  -0.5526607j  0.7067186 +1.0906978j  0.5100653 -0.30781755j
#  0.27592745-0.15025401j]
# [1.        +0.j         1.0475981 -0.5336121j  0.9669171 +0.15119712j
#  0.95435005-0.1468581j  0.96313477+0.2457154j  0.5492806 -0.12015956j
#  1.0591577 -0.50882494j 0.5063958 +0.6414346j  0.7737447 +0.45605114j
#  0.8745617 -0.10712893j 1.2393118 +0.91278726j 0.49979877-0.15471567j
#  0.2848783 -0.05865132j]
# [1.        +0.j         0.7067923 +0.41467935j 1.0459101 -0.05104547j
#  0.80464613+0.35346565j 0.9917063 -0.12449578j 1.0979135 +0.04063158j
#  0.6090071 -0.04810933j 0.87707365-0.06338689j 1.0053967 +0.29665038j
#  1.1180873 +0.20660481j 0.6356607 -0.07859844j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         1.0708436 -0.35361502j 0.67737335+0.5270741j
#  1.0129386 -0.4016243j  1.0307571 +0.16850704j 0.5284011 -0.09837252j
#  0.04045644+0.6960552j  0.9591913 -0.5653548j  0.91462547-0.451921j
#  0.7655322 +0.5368602j  1.4975253 +0.8406756j  0.4746741 -0.09235885j
#  0.2644311 -0.04032955j]
# [1.        +0.j         0.76947314+0.37672916j 0.988391  +0.03749115j
#  0.9417464 +0.23295829j 0.97781044-0.26600894j 1.4012504 +0.5941594j
#  0.5256886 -0.09259743j 0.7469891 +0.51018184j 0.893356  -0.42431247j
#  0.26335284-0.03124615j]
# [1.        +0.j         0.9185339 -0.5719118j  0.7288977 +0.54917467j
#  0.5977567 -0.35484418j 0.80743545-0.829779j   0.1827066 +0.7989534j
#  0.44856614-0.55844176j 0.2678313 -0.2814175j ]
# [1.        +0.j         0.72580963+0.4015947j  1.027556  -0.0122059j
#  0.8540713 +0.30576158j 0.94977844-0.045159j   0.96663946+0.19379076j
#  0.95602834-0.1403186j  1.6373178 +0.40753356j 0.5413992 -0.00511222j
#  0.793424  +0.4469484j  0.864854  -0.1598113j ]
# [1.        +0.j         0.84530973+0.28843388j 0.98004746-0.22728848j
#  0.9153615 +0.31680512j 0.5939756 -0.24167995j 0.3942438 +0.6619782j
#  0.965036  -0.17488873j 0.66908854+0.62360543j 0.5169381 -0.37497246j
#  0.286907  -0.17475429j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         0.92269415-0.6494658j  0.6191038 +0.58834076j
#  0.96949375-0.19690038j 0.9088319 +0.34038562j 0.5634349 -0.1945016j
#  0.77229524-0.9748715j  0.8742808 +1.0884346j  0.5043874 -0.2521686j
#  0.26545987-0.12874506j]
# [1.        +0.j         0.8514698 -0.7175994j  0.80961335+0.9378054j
#  0.57316995-0.26340112j 0.2720029 -1.1894351j  0.26828158-0.18665399j]
# [1.        +0.j         0.90729636+0.22409672j 0.60819733-0.39745525j
#  0.60234565+0.61901385j 0.41840625-0.6457375j  0.26655674-0.32567886j]
# [1.        +0.j         0.84874505-0.8065712j  0.96196353+0.27137667j
#  0.55202657-0.17443232j 0.2592917 -1.2954494j  0.6640388 -0.9490839j
#  0.42095384+0.73277605j 1.0607035 +1.0489924j  0.49967524-0.19498351j
#  0.2570747 -0.11107918j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         0.9185339 -0.5719118j  0.7288977 +0.54917467j
#  0.5977567 -0.35484418j 0.80743545-0.829779j   0.1827066 +0.7989534j
#  0.44856614-0.55844176j 0.2678313 -0.2814175j ]
# [1.        +0.j         0.94018227+0.08485841j 0.9145295 +0.09560632j
#  1.0121855 +0.12785114j 0.97482854-0.1747494j  1.5726056 +0.4243752j
#  0.5580829 -0.01392761j 0.6047098 +0.472701j   0.92857224+0.33971864j
#  0.9015909 -0.2694405j ]
# [1.        +0.j         0.92902404-0.6070198j  0.68587977+0.5507169j
#  0.96495587-0.36140576j 1.2370089 +0.73432124j 0.5379605 -0.15144181j
#  0.8057523 -0.90282935j 0.08893169+0.73837376j 0.86435765-0.54038084j
#  0.24869958-0.08835765j]
# [1.        +0.j         1.0569977 -0.31254968j 0.7247218 +0.510117j
#  0.9733756 -0.29245028j 0.88175285+0.36546865j 0.57140154-0.20824778j
#  0.14855538+0.74219877j 0.91546005-0.397134j   0.77819127+1.0893764j
#  0.50775313-0.2850407j  0.27151588-0.14088726j]
# [1.        +0.j         1.0712804 -0.4417582j  0.56326205+0.59413815j
#  1.0269352 -0.23650976j 1.0645573 +0.08688969j 0.5595307 -0.12718503j
#  0.9432836 -0.18685804j 0.8787949 +0.43421692j 1.0301464 +0.3258667j
#  0.5142083 -0.18233053j 0.29397762-0.06720559j]
# [1.       +0.j         0.8864701-0.71177787j 0.6043934+0.5912468j
#  0.962908 -0.2716431j  1.3063114+0.72195035j 0.5268831-0.13056512j
#  0.3914889-1.1993637j  0.2401394-0.07197826j]
# [1.        +0.j         0.8418652 +0.26735368j 1.0244465 -0.41111895j
#  0.73048913+0.42517132j 1.0025601 -0.24058329j 1.9466884 +0.26586765j
#  0.4758644 +0.03713675j 0.44047529+0.6132331j  0.93142253-0.6903577j
#  0.9030473 -0.23356044j 2.7952712 +1.5221417j ]
# [1.        +0.0000000e+00j 0.845824  -9.1222978e-01j
#  1.0501583 +3.7623748e-02j 0.939011  -9.6847728e-02j
#  1.735055  +3.7421522e-01j 0.51651686+6.9061003e-04j
#  0.4983357 -1.3719857e+00j 0.6515846 -1.1648921e+00j
#  0.9075183 +3.2759038e-01j 0.9648183 +2.8357446e-01j
#  0.82373   -2.9196931e-02j]
# [1.        +0.j         0.6979822 +0.4412296j  1.042203  -0.084811j
#  1.0746233 +0.03945255j 0.58644485-0.15272155j 0.94865036+0.0291216j
#  0.9283867 +0.35812956j 1.0765681 +0.23453024j 0.54401076-0.24372046j
#  0.32168728-0.09102353j]
# [1.        +0.j         0.8830133 -0.7510626j  0.99060565+0.20118812j
#  0.57972467-0.21444768j 0.6641089 -1.115111j   0.774593  -0.8339153j
#  0.49492055+0.70737j    0.8318125 +0.5200342j  0.51374   -0.3182217j
#  0.2761194 -0.15009335j]
# [1.        +0.j         0.68957406+0.41156346j 1.0627822 -0.06411052j
#  0.7745959 +0.35644776j 1.024928  -0.1543485j  1.0014278 +0.1084383j
#  0.95959187+0.05576528j 0.9528595 +0.04213559j 0.94984156-0.12014204j
#  0.8266354 +0.3664574j  1.5494764 +0.19159031j]
# [1.        +0.j         1.0388024 -0.2565779j  0.7845435 +0.48848462j
#  0.60497206-0.37725136j 0.30358863+0.7869067j  0.43418032-0.6078015j
#  0.2682628 -0.30565053j]
# ...
# [1.        +0.j         1.0464656 -0.3581884j  0.68503094+0.5579916j
#  0.96562684-0.3204888j  0.8637129 +0.4050933j  0.55481565-0.23202285j
#  0.01900865+0.7520104j  0.90380853-0.42901406j 0.6387334 +1.1828653j
#  0.48508042-0.30890292j 0.2553789 -0.15186954j]
# [1.        +0.j         1.0464656 -0.3581884j  0.68503094+0.5579916j
#  0.96562684-0.3204888j  0.8637129 +0.4050933j  0.55481565-0.23202285j
#  0.01900865+0.7520104j  0.90380853-0.42901406j 0.6387334 +1.1828653j
#  0.48508042-0.30890292j 0.2553789 -0.15186954j]
# [1.        +0.j         0.8060076 +0.32373697j 0.9918246 -0.61301434j
#  1.1086001 +0.00870975j 0.52795494-0.01566335j 0.29623914+0.66195494j
#  0.79522586-0.98086584j 0.8576483 -0.81884j    1.0374169 +0.2831227j
#  2.0218058 +0.45866153j 0.49486652+0.04169375j]
# [1.        +0.j         0.83370465-0.90259725j 0.89038247+0.25857794j
#  1.0419822 -0.35993856j 2.1541944 -0.17125052j 0.48583907-1.350474j
#  0.703108  -1.0623281j  0.26586035+0.6840838j  0.5109561 +0.5806226j
#  1.0003387 -0.40490088j 0.98184466-0.45835295j 4.313034  +0.33842102j]
# [1.        +0.j         0.76079726+0.41988146j 0.9754873 +0.04716463j
#  0.9617349 +0.24586533j 0.58387333-0.2852252j  0.78317744+0.55639756j
#  0.48198444-0.44774252j 0.27230126-0.20509975j]
# [1.        +0.j         0.7833898 -0.7959498j  0.67422456+1.034592j
#  0.5558349 -0.29173496j 0.06683774-1.2257048j  0.2508374 -0.20029037j]
# [1.        +0.j         0.87754494-0.7148039j  0.5542209 +0.6463355j
#  0.9684512 -0.20744759j 0.8939551 +0.3760448j  0.54791576-0.21704651j
#  0.66228604-1.062344j   0.7443857 +1.1876489j  0.48513317-0.2732735j
#  0.25048947-0.13904165j]
# [1.        +0.j         0.7403708 +0.4256945j  0.99009085+0.03688239j
#  0.9346652 +0.25503272j 0.9688907 -0.2935404j  1.3827293 +0.67547053j
#  0.51505774-0.09966595j 0.71214134+0.5543522j  0.8725452 -0.4627682j
#  0.2515602 -0.03082446j]
# [1.        +0.j         1.0227379 -0.04944918j 0.5890916 -0.29590186j
#  0.798859  +0.3918079j  0.9957604 +0.20389874j 0.48145348-0.47217616j
#  0.27493075-0.21605204j]
# [1.        +0.j         1.0492418 -0.50095636j 0.49729553+0.64683306j
#  1.0226265 -0.26299015j 1.0655001 +0.08554701j 0.54655117-0.1413066j
#  0.94206506-0.19947766j 0.85747737+0.47336158j 1.0244797 +0.3487627j
#  0.49740708-0.19930692j 0.27960536-0.07193831j]
# [1.        +0.j         0.9496134 +0.09597385j 0.9006879 +0.11178726j
#  1.0369054 +0.12973101j 0.5776843 -0.17638405j 0.5780329 +0.53194374j
#  0.98991406+0.36042428j 0.52640784-0.28185993j 0.3113617 -0.10334007j]
# [ 1.        +0.j          0.8241903 -0.72721237j  0.6281009 +0.63817114j
#   0.55922997-0.36334798j  0.27087858-1.1619912j  -0.23676576+1.0800989j
#   0.42954904-0.5111413j   0.2372874 -0.26746458j]
# [1.        +0.j         0.8100923 +0.33506268j 0.9957646 -0.2717043j
#  0.859745  +0.35851243j 0.9601027 -0.2610569j  1.4276907 +0.6692031j
#  0.5068628 -0.09010841j 0.26393992+0.6890948j  0.9959185 -0.23228574j
#  0.492682  +0.66113645j 0.87417376-0.35055676j 0.24360327-0.02413506j]
# [1.        +0.j         1.0210406 -0.6232369j  0.9458611 +0.17045897j
#  0.98539835-0.18813168j 0.8781502 +0.3068496j  0.9249851 -0.08052793j
#  1.7554761 +0.4340503j  0.5031577 +0.00867844j 1.0410783 -0.61716866j
#  0.4045269 +0.67409146j 0.6940431 +0.5008017j  0.92301476-0.145981j  ]
# [1.        +0.j         0.87754494-0.7148039j  0.5542209 +0.6463355j
#  0.9684512 -0.20744759j 0.8939551 +0.3760448j  0.54791576-0.21704651j
#  0.66228604-1.062344j   0.7443857 +1.1876489j  0.48513317-0.2732735j
#  0.25048947-0.13904165j]
# [1.        +0.j         0.8720679 +0.27302998j 0.94702476-0.47502074j
#  1.0922935 +0.8479427j  0.53963965-0.19106022j 0.47970265+0.66600484j
#  0.73692435-0.8095565j  0.24854735-0.11245613j]
# [1.        +0.j         0.8720679 +0.27302998j 0.94702476-0.47502074j
#  1.0922935 +0.8479427j  0.53963965-0.19106022j 0.47970265+0.66600484j
#  0.73692435-0.8095565j  0.24854735-0.11245613j]
# [1.        +0.j         0.76079726+0.41988146j 0.9754873 +0.04716463j
#  0.9617349 +0.24586533j 0.58387333-0.2852252j  0.78317744+0.55639756j
#  0.48198444-0.44774252j 0.27230126-0.20509975j]
# [1.        +0.j         1.0547196 -0.04609463j 0.9102086 +0.127187j
#  0.98666227+0.02898974j 1.0145081 +0.0306833j  0.9140639 +0.107944j  ]
# [1.        +0.j         1.0086086 -0.03757221j 0.9741161 -0.3122323j
#  1.355521  +0.6808809j  0.51978004-0.10566801j 0.7627387 +0.4015418j
#  0.9522936 +0.22211076j 0.8729537 -0.5172327j  0.25605917-0.03529205j]
# [1.        +0.j         0.964514  +0.02980837j 0.98498607-0.15966389j
#  0.89393485+0.2849787j  0.91785043-0.05623051j 1.0144678 +0.17601344j
#  0.57359326-0.04115223j 0.64770603+0.45953968j 0.782545  +0.36687785j
#  0.9252837 -0.05342798j 1.5683357 +0.7679937j  0.57470506-0.03843546j]
# [ 1.        +0.j          1.0575012 -0.40304282j  0.6330997 +0.5752981j
#   0.99457777-0.44928056j  1.0304747 +0.1778959j   0.51722556-0.10894391j
#  -0.09351336+0.6859915j   0.9278494 -0.62159693j  0.8938214 -0.49342492j
#   0.72728515+0.5877275j   1.4667225 +0.9340201j   0.46419075-0.09665113j
#   0.2523314 -0.04280526j]
# [1.        +0.j         0.8704779 -0.8083747j  0.43614495+0.6593579j
#  1.0275601 -0.36716953j 0.9688897 +0.19946541j 0.88950455+0.01954114j
#  1.8854568 +0.37587366j 0.47677296+0.02040648j 0.59234846-1.2243397j
#  0.96700233-0.37589756j 0.6357692 +0.57449734j]
# [1.        +0.j         0.86514676-0.78615934j 0.45839578+0.66699964j
#  1.0076822 -0.3356326j  1.0486807 +0.14332168j 0.51010287-0.10169113j
#  0.5980378 -1.1800555j  0.9222896 -0.3124566j  0.79056567+0.54771674j
#  1.5647811 +0.8814347j  0.455726  -0.08048674j 0.24527842-0.03807418j]
# [1.        +0.j         1.0319172 -0.29719764j 0.7504009 +0.53436095j
#  0.57043016-0.42216152j 0.19027734+0.816235j   0.3534478 -0.65454715j
#  0.22841948-0.3283919j ]
# [ 1.        +0.j          0.8241903 -0.72721237j  0.6281009 +0.63817114j
#   0.55922997-0.36334798j  0.27087858-1.1619912j  -0.23676576+1.0800989j
#   0.42954904-0.5111413j   0.2372874 -0.26746458j]
# [1.        +0.j         0.86514676-0.78615934j 0.45839578+0.66699964j
#  1.0076822 -0.3356326j  1.0486807 +0.14332168j 0.51010287-0.10169113j
#  0.5980378 -1.1800555j  0.9222896 -0.3124566j  0.79056567+0.54771674j
#  1.5647811 +0.8814347j  0.455726  -0.08048674j 0.24527842-0.03807418j]
# [1.        +0.j         0.7833898 -0.7959498j  0.67422456+1.034592j
#  0.5558349 -0.29173496j 0.06683774-1.2257048j  0.2508374 -0.20029037j]
# [1.        +0.j         1.0319172 -0.29719764j 0.7504009 +0.53436095j
#  0.57043016-0.42216152j 0.19027734+0.816235j   0.3534478 -0.65454715j
#  0.22841948-0.3283919j ]
# [1.        +0.j         0.65859044+0.49360746j 1.0424124 -0.1053527j
#  1.0750192 +0.03630344j 0.5718882 -0.16883923j 0.9506653 +0.02163853j
#  0.91281873+0.39283428j 1.0742043 +0.24837694j 0.5218729 -0.26557106j
#  0.3051237 -0.09678567j]
# [1.        +0.j         1.0319172 -0.29719764j 0.7504009 +0.53436095j
#  0.57043016-0.42216152j 0.19027734+0.816235j   0.3534478 -0.65454715j
#  0.22841948-0.3283919j ]
# [1.        +0.j         0.7761436 +0.3705667j  1.0081029 -0.39406934j
#  1.0493106 +0.12215653j 0.5521942 -0.14794387j 0.14627795+0.6863165j
#  1.0220547 -0.41136935j 0.9243203 -0.397784j   0.79444003+0.5270092j
#  0.98546225+0.3951851j  0.50231427-0.21214844j 0.2856942 -0.07677335j]
# [1.        +0.j         0.9843577 -0.800137j   0.9981405 +0.07160354j
#  0.88412684+0.08339088j 1.0196694 +0.10992365j 1.047606  -0.06423593j
#  1.6652551 +0.16040182j 0.936008  -1.0234911j  0.8066891 +0.36505237j
#  0.91637856+0.32024688j 1.0201895 -0.03278925j]
# [ 1.        +0.j          0.8241903 -0.72721237j  0.6281009 +0.63817114j
#   0.55922997-0.36334798j  0.27087858-1.1619912j  -0.23676576+1.0800989j
#   0.42954904-0.5111413j   0.2372874 -0.26746458j]
# [1.        +0.j         1.0640923 -0.44940498j 0.5619672 +0.6067555j
#  1.0109793 -0.15454707j 0.8557319 +0.33717442j 1.0064502 -0.3219021j
#  1.9391162 +0.32988974j 0.46880534+0.03662994j 0.45853773+0.63577974j
#  0.93993413-0.41145006j 0.9041211 -0.348662j   2.6146073 +1.7558669j ]
# [1.        +0.j         0.8948453 +0.2577202j  0.5712498 -0.44345877j
#  0.5337771 +0.6715638j  0.33033556-0.6913219j  0.2235417 -0.34845105j]
# [ 1.        +0.j         0.44212624-0.678439j  -0.19364622-0.8833924j
#   0.04782481-0.5060838j]
# [1.        +0.j         0.88423616-0.6296651j  0.6822048 +0.6019335j
#  0.5660416 -0.39793056j 0.72532344-0.91255504j 0.04435684+0.8134384j
#  0.37889546-0.6045183j  0.23205882-0.3035113j ]
# [1.        +0.j         0.99788505-0.02776415j 1.0194753 -0.3949527j
#  1.8475351 +0.37559226j 0.48633364+0.03097053j 0.73677343+0.40411112j
#  0.9186944 +0.23826739j 0.91936845-0.6534389j  0.9111719 -0.47562858j
#  2.248639  +1.7670745j ]
# [1.        +0.j         1.0086086 -0.03757221j 0.9741161 -0.3122323j
#  1.355521  +0.6808809j  0.51978004-0.10566801j 0.7627387 +0.4015418j
#  0.9522936 +0.22211076j 0.8729537 -0.5172327j  0.25605917-0.03529205j]
# [1.        +0.j         1.0227379 -0.04944918j 0.5890916 -0.29590186j
#  0.798859  +0.3918079j  0.9957604 +0.20389874j 0.48145348-0.47217616j
#  0.27493075-0.21605204j]
# [1.        +0.j         1.01509   -0.58365107j 0.9852143 +0.1355687j
#  0.9668323 -0.27512082j 1.4187473 +0.66254056j 0.50840867-0.09433351j
#  1.0265578 -0.54042864j 0.48722574+0.68070877j 0.83311874+0.4379531j
#  0.8766112 -0.41601098j 0.24487339-0.02825205j]
# [1.        +0.j         0.8158753 -0.8283594j  0.9872763 +0.21148005j
#  0.56224847-0.2397309j  0.5098834 -1.2023993j  0.6965255 -0.9066355j
#  0.41048214+0.7553184j  0.8030547 +0.56031376j 0.484758  -0.34863657j
#  0.25856426-0.16234882j]
# [1.        +0.j         0.99788505-0.02776415j 1.0194753 -0.3949527j
#  1.8475351 +0.37559226j 0.48633364+0.03097053j 0.73677343+0.40411112j
#  0.9186944 +0.23826739j 0.91936845-0.6534389j  0.9111719 -0.47562858j
#  2.248639  +1.7670745j ]
# [1.        +0.j         0.8158753 -0.8283594j  0.9872763 +0.21148005j
#  0.56224847-0.2397309j  0.5098834 -1.2023993j  0.6965255 -0.9066355j
#  0.41048214+0.7553184j  0.8030547 +0.56031376j 0.484758  -0.34863657j
#  0.25856426-0.16234882j]
# [1.        +0.j         0.76079726+0.41988146j 0.9754873 +0.04716463j
#  0.9617349 +0.24586533j 0.58387333-0.2852252j  0.78317744+0.55639756j
#  0.48198444-0.44774252j 0.27230126-0.20509975j]
# [1.        +0.j         0.7833898 -0.7959498j  0.67422456+1.034592j
#  0.5558349 -0.29173496j 0.06683774-1.2257048j  0.2508374 -0.20029037j]
# [1.        +0.j         0.964514  +0.02980837j 0.98498607-0.15966389j
#  0.89393485+0.2849787j  0.91785043-0.05623051j 1.0144678 +0.17601344j
#  0.57359326-0.04115223j 0.64770603+0.45953968j 0.782545  +0.36687785j
#  0.9252837 -0.05342798j 1.5683357 +0.7679937j  0.57470506-0.03843546j]
# [1.        +0.j         0.76079726+0.41988146j 0.9754873 +0.04716463j
#  0.9617349 +0.24586533j 0.58387333-0.2852252j  0.78317744+0.55639756j
#  0.48198444-0.44774252j 0.27230126-0.20509975j]
# [1.        +0.j         1.0517077 -0.08782522j 1.0301409 -0.2312667j
#  0.9729542 +0.02975251j 0.9686476 +0.0486341j  1.0131689 +0.11177181j
#  0.97758037-0.32222727j 1.0314794 -0.24928081j 0.8628282 +0.26154816j
#  1.628588  +0.19468173j]
# [1.        +0.j         0.8815042 -0.7462233j  0.519167  +0.6434918j
#  0.99851143-0.24106139j 0.8101161 +0.41157386j 0.93609446-0.1279347j
#  1.5775491 +0.6249164j  0.48204887-0.06281003j 0.6487586 -1.1227129j
#  0.22002272-0.00716529j]
# [1.        +0.j         0.7833898 -0.7959498j  0.67422456+1.034592j
#  0.5558349 -0.29173496j 0.06683774-1.2257048j  0.2508374 -0.20029037j]
# [1.        +0.j         1.0934194 -0.1357078j  0.5837215 -0.18336186j
#  1.0513502 -0.02393026j 1.1513779 +0.00113428j 0.53270715-0.29941425j
#  0.317048  -0.1109783j ]
# [1.        +0.j         0.7403708 +0.4256945j  0.99009085+0.03688239j
#  0.9346652 +0.25503272j 0.9688907 -0.2935404j  1.3827293 +0.67547053j
#  0.51505774-0.09966595j 0.71214134+0.5543522j  0.8725452 -0.4627682j
#  0.2515602 -0.03082446j]
# [1.        +0.j         1.0540988 -0.43598637j 0.57865465+0.6112997j
#  0.9961459 -0.1370729j  0.8899393 +0.32206717j 0.9575005 -0.24245815j
#  1.4601374 +0.6570945j  0.5011932 -0.08526488j 0.55474186+0.63911325j
#  0.8747309 -0.29778385j 0.23808531-0.02161395j]
# [1.        +0.j         0.95523846+0.03402332j 1.0042014 -0.17307423j
#  0.8589222 +0.29113123j 0.95743585-0.08106639j 0.92706984+0.21833365j
#  1.0015903 +0.0048505j  1.7344679 +0.12443873j 0.62909234+0.4535994j
#  0.75703686+0.36542857j 0.9538429 -0.07115655j]
# [1.        +0.j         0.8876461 -0.7680898j  0.49502894+0.6383677j
#  1.018636  -0.27638933j 0.74660957+0.43923947j 0.99014443-0.20384112j
#  2.039847  +0.26578808j 0.4507171 +0.04386332j 0.6465769 -1.1664547j
#  0.8847212 -0.16196904j 3.0518632 +1.6940275j ]
# [1.        +0.j         0.74215245+0.38991815j 1.0184377 -0.5127655j
#  1.123686  -0.02947552j 0.5815257 -0.04884754j 0.06836502+0.65438324j
#  1.0344294 -0.60028344j 0.93815666-0.64811146j 1.0869639 +0.2005246j
#  1.1711464 +0.13126892j 0.5960593 -0.07154886j]
# [1.        +0.j         0.7975165 +0.3368203j  1.0103972 -0.29227224j
#  0.824722  +0.37188226j 1.0074483 -0.34276962j 1.9124774 +0.33999395j
#  0.47409156+0.0366659j  0.24381056+0.6731795j  1.0198982 -0.26451504j
#  0.39834696+0.65103567j 0.9337781 -0.47105995j 0.90486175-0.37873995j
#  2.5029008 +1.7652419j ]
# [1.        +0.j         1.0319172 -0.29719764j 0.7504009 +0.53436095j
#  0.57043016-0.42216152j 0.19027734+0.816235j   0.3534478 -0.65454715j
#  0.22841948-0.3283919j ]
# [ 1.        +0.j          1.0575012 -0.40304282j  0.6330997 +0.5752981j
#   0.99457777-0.44928056j  1.0304747 +0.1778959j   0.51722556-0.10894391j
#  -0.09351336+0.6859915j   0.9278494 -0.62159693j  0.8938214 -0.49342492j
#   0.72728515+0.5877275j   1.4667225 +0.9340201j   0.46419075-0.09665113j
#   0.2523314 -0.04280526j]
# [1.        +0.j         1.0804646 -0.12530297j 0.97729796-0.20594594j
#  1.5592836 +0.48981088j 0.5487261 -0.01775307j 1.0248758 -0.00560445j
#  1.1092769 +0.02416389j 0.904346  -0.3344901j ]
# [ 1.        +0.j         0.44212624-0.678439j  -0.19364622-0.8833924j
#   0.04782481-0.5060838j]
# [1.        +0.j         0.9823894 +0.0098385j  0.9495444 -0.11880097j
#  0.9827862 +0.22463611j 0.5660629 -0.16496421j 0.69111836+0.44923046j
#  0.8420147 +0.33890462j 0.86852366-0.00085562j 0.8478753 +0.5023735j
#  0.51429427-0.25184324j 0.30003396-0.09139656j]
# [1.        +0.j         1.0227379 -0.04944918j 0.5890916 -0.29590186j
#  0.798859  +0.3918079j  0.9957604 +0.20389874j 0.48145348-0.47217616j
#  0.27493075-0.21605204j]
# [ 1.        +0.j          0.69982463-1.0182964j   1.0794039 +0.06383839j
#   0.49995053-0.09048638j -0.19509216-1.4311492j   0.36342737-1.261003j
#   0.91837466+0.424631j    1.7355456 +0.7466795j   0.4428638 -0.05142587j
#   0.23539938-0.03077414j]
# [1.        +0.j         0.88423616-0.6296651j  0.6822048 +0.6019335j
#  0.5660416 -0.39793056j 0.72532344-0.91255504j 0.04435684+0.8134384j
#  0.37889546-0.6045183j  0.23205882-0.3035113j ]
# [1.        +0.j         0.7833898 -0.7959498j  0.67422456+1.034592j
#  0.5558349 -0.29173496j 0.06683774-1.2257048j  0.2508374 -0.20029037j]
# [1.        +0.j         0.88423616-0.6296651j  0.6822048 +0.6019335j
#  0.5660416 -0.39793056j 0.72532344-0.91255504j 0.04435684+0.8134384j
#  0.37889546-0.6045183j  0.23205882-0.3035113j ]
# [1.        +0.j         1.0492418 -0.50095636j 0.49729553+0.64683306j
#  1.0226265 -0.26299015j 1.0655001 +0.08554701j 0.54655117-0.1413066j
#  0.94206506-0.19947766j 0.85747737+0.47336158j 1.0244797 +0.3487627j
#  0.49740708-0.19930692j 0.27960536-0.07193831j]
# [1.        +0.j         1.0252848 -0.6000394j  0.9665527 +0.14775562j
#  1.0148454 -0.3546146j  1.901459  +0.35280928j 0.4755843 +0.03267348j
#  1.0433801 -0.5722811j  0.4535194 +0.669495j   0.7772905 +0.45233604j
#  0.93331254-0.5403611j  0.9101605 -0.40973663j 2.463939  +1.7603407j ]
# [1.        +0.j         0.7013302 -1.1216654j  1.0788865 -0.14260413j
#  0.09453836-1.614549j   0.24306527-1.5180515j  1.1382427 -0.15207797j
#  1.0653689 -0.11496019j]
# [1.        +0.j         0.9496134 +0.09597385j 0.9006879 +0.11178726j
#  1.0369054 +0.12973101j 0.5776843 -0.17638405j 0.5780329 +0.53194374j
#  0.98991406+0.36042428j 0.52640784-0.28185993j 0.3113617 -0.10334007j]
# mean(E): (2.2500622272491455-0.0048993052914738655j), var(E): 0.0864882692694664, #samples 200, #Step 10
#
#
# (1024, 10)

# %% [markdown]
# ## **Comparison of RNN results with ED**

# %% [markdown]
# After we got the variational energies for each time step, we can now compare the RNN results with exact diagonalization

# %%
#Computing the ground state energy by taking average over the last 100 iterations
print("Ground state energy = ", np.mean(RNNEnergy[-100:]), "+-", np.sqrt(np.max(varRNNEnergy[-100:])/(numsamples*100))) #We use np.max(varRNNEnergy[-100:]) to estimate an upper bound on the error
print("Exact ground state energy = ", E_exact)
# Out:
# Ground state energy =  (-3.9647076-0.00012957472j) +- 0.002005918529793412
# Exact ground state energy =  -3.9855798336170905

# %% [markdown]
# Awesome! We can also plot the variational energy and the energy variance where we observe convergence during the last iterations

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax.plot(np.arange(1, len(RNNEnergy)+1), RNNEnergy, "b-", label="Variational energy of the RNN")
ax.plot(np.arange(1, len(RNNEnergy)+1), [E_exact]*len(RNNEnergy), "k--", label="Exact energy")

ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Variational energy', fontsize = 25)
plt.legend()

plt.show()
# Out:
# C:\Users\Administrator\anaconda3\envs\RNN\lib\site-packages\numpy\core\numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### **Energy variance**

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax.semilogy(np.arange(1, len(RNNEnergy)+1), varRNNEnergy, "b-", label="Energy variance of the RNN")

ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Energy variance', fontsize = 25)
plt.legend()

plt.show()

# %% [markdown]
# In the beginning, the variance is small since the cRNN wavefunction was initially trapped in a local mimimum.

# %% [markdown]
# ## **Explorations**

# %% [markdown]
# - If you want to explore large system sizes with the cRNN wavefunction, here are some ground states energy of J1-J2 model (with open boundary conditions) given by DMRG and can be considered exact:
#
# > N = 100 (J1 = 1)
#  >>  J2 = 0.0: -44.127739860
#
#  >>  J2 = 0.2: -40.73881897
#
#  >>  J2 = 0.5 (Majumdar-Ghosh point): -37.5
#
#  >>  J2 = 0.8: -42.07006
#
# - You can also play with the hyperparameters (memory units, number of layers, number of samples, learning rate, Marshall sign) to obtain better accuracies.
