# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

E1 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle0.0_seed3.npy")
E2 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle0.15707963267948966_seed3.npy")
E3 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle0.3141592653589793_seed3.npy")
E4 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle0.47123889803846897_seed3.npy")
E5 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle0.6283185307179586_seed3.npy")
E6 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle0.7853981633974483_seed3.npy")
E7 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle0.9424777960769379_seed3.npy")
E8 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle1.0995574287564276_seed3.npy")
E9 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle1.2566370614359172_seed3.npy")
E10 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle1.413716694115407_seed3.npy")
E11 = np.load("result/meanE_L64_units64_cmi_pattern_no_decayrotationTrueangle1.5707963267948966_seed3.npy")
E12 = np.append(np.load("result/meanE_L64_units32_cmi_pattern_no_decayrotationTrueangle1.0995574287564276_seed4.npy"), np.load("result/meanE_L64_units32_cmi_pattern_no_decayrotationTrueangle1.5707963267948966_seed4.npy"))
E13 = np.load("result/meanE_L64_units32_cmi_pattern_no_decayrotationTrueangle1.5707963267948966_seed5.npy")

# %%
Ea = np.reshape(E11,(6 ,-1))
Eb = np.reshape(E10,(5 ,-1))
for i in range (6):
    plt.plot(Ea[i,:], label = str(2*i))
    if i< 5:
        plt.plot(Eb[i,:], label = str(2*i+1))
plt.legend()
plt.ylim(-64, -48)
plt.show()

# %%
E = np.empty((11, 8000))
for i in range (6):
    E[2*i] = np.real(Ea[i])
    if i< 5:
        E[2*i+1] = np.real(Eb[i])

# %%
plt.plot(E11.ravel(), label = "unit_64")
plt.plot(E12.ravel(), label = "unit_32")
plt.ylabel("Energy")
plt.title("Different basis comparison 1D ES with L = 64")
plt.ylim(-64, -48)
plt.legend()

# %%
plt.plot(E13.ravel(), label = "unit_32")
plt.ylim(-64, -48)
# Out:
# (-64.0, -48.0)
