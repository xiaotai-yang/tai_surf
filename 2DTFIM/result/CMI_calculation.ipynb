# %%
import numpy as np
label = ["0.5", "1.0", "1.5","2.0","3.0","3.5"]

# %%
data = [[] for i in range (len(label))]
first_var = [[] for i in range (len(label))]
second_var = [[] for i in range (len(label))]
for i in range (len(label)):
    for j in range (40):
        data[i].append(np.load(label[i]+"/tv_"+label[i]+"y9x4_param"+str(40*i+j+1)+".npy"))
        first_var[i].append(np.load(label[i]+"/tv_first_var"+label[i]+"y9x4_param"+str(40*i+j+1)+".npy"))
        second_var[i].append(np.load(label[i]+"/tv_second_var"+label[i]+"y9x4_param"+str(40*i+j+1)+".npy"))

# %%
data=np.array(data)
first_var = np.array(first_var)
second_var = np.array(second_var)
print(data.shape)
# Out:
# (6, 40, 1, 13)

# %%
data_mean = np.mean(data, axis = (1,2))
first_var_mean = np.mean(first_var, axis=(1,2))
second_var_mean = np.mean(second_var, axis=(1,2))
data_mean[2]*=40./39.

# %%
import matplotlib.pyplot as plt
for i in range (len(label)):
    plt.plot(np.arange(13), (data_mean[i]), label=label[i], alpha=0.4)
plt.xlabel("distance")
plt.ylabel("TV")
plt.title("2DTFIM_CMI_decay")
plt.legend(loc="lower right")

plt.savefig("2DTFIM_CMI.png", dpi = 150)

# %%
import matplotlib.pyplot as plt
for i in range (len(label)):
    plt.plot(np.arange(13), np.log(data_mean[i]+1e-12), label=label[i], alpha=0.4)
plt.xlabel("distance")
plt.ylabel("log_TV")
plt.title("2DTFIM_log_CMI_decay")
plt.legend(loc="lower right")
plt.legend()
plt.savefig("2DTFIM_log_CMI_decay", dpi=150)

# %%
import numpy as np

# %%
data2= np.array([])
first_var2 = np.array([])
second_var2 = np.array([])
for i in range(160):
    data2 = np.append(data2, np.load("0.2/tv_0.2y9x4_param"+str(i+1)+".npy"))
    first_var2 = np.append(first_var2, np.load("0.2/tv_first_var0.2y9x4_param"+str(i+1)+".npy"))
    second_var2 = np.append(second_var2, np.load("0.2/tv_second_var0.2y9x4_param"+str(i+1)+".npy"))

# %%
data2 = np.reshape(data2,(i+1, 13))
print(data2)
first_var2 = np.reshape(first_var2,(i+1, 13))
second_var2 = np.reshape(second_var2, (i+1, 13))
# Out:
# [[0.75269739 0.38451184 0.47949762 ... 0.41006763 0.33136893 0.34509967]
#  [0.77837598 0.39088623 0.41781299 ... 0.40828775 0.31337048 0.35463043]
#  [0.79267474 0.40582391 0.49929895 ... 0.37760077 0.28006912 0.31994986]
#  ...
#  [0.78667639 0.38668808 0.46071704 ... 0.42321811 0.29578168 0.30741373]
#  [0.76418665 0.37123691 0.46210388 ... 0.38458401 0.26737335 0.33824927]
#  [0.78666876 0.39083328 0.48244455 ... 0.45079388 0.24636441 0.35896652]]

# %%
data2 = np.mean(data2, axis=0)
first_var2 = np.mean(first_var2, axis=0)
second_var2 = np.mean(second_var2, axis=0)

# %%
print(first_var2)
print(second_var2)
# Out:
# [0.04701221 0.2108297  0.13027818 0.13120888 0.13437642 0.1201074
#  0.13811657 0.11574866 0.13881678 0.11342749 0.1329119  0.09440151
#  0.10530634]
# [0.16871882 0.05527543 0.0859122  0.05713077 0.06932206 0.05696859
#  0.06864111 0.05538115 0.06873083 0.05588858 0.0650623  0.0456988
#  0.04763556]

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(13), data2, label="0.2")

# %%
print(data2)
# Out:
# [0.7935222  0.37852258 0.46545148 0.34442671 0.41543308 0.3389923
#  0.41748075 0.33002618 0.41256826 0.33040859 0.39423609 0.28546826
#  0.33097792]

# %%
data2= np.array([])
first_var2 = np.array([])
second_var2 = np.array([])
for i in range(160):
    data2 = np.append(data2, np.load("0.2_old/tv_0.2y9x4_param"+str(i+1)+".npy"))
    first_var2 = np.append(first_var2, np.load("0.2_old/tv_first_var0.2y9x4_param"+str(i+1)+".npy"))
    second_var2 = np.append(second_var2, np.load("0.2_old/tv_second_var0.2y9x4_param"+str(i+1)+".npy"))

# %%
data2 = np.reshape(data2,(i+1, 13))
print(data2)
first_var2 = np.reshape(first_var2,(i+1, 13))
second_var2 = np.reshape(second_var2, (i+1, 13))
# Out:
# [[0.54731116 0.34371609 0.38625641 ... 0.27175336 0.22829114 0.28111292]
#  [0.88372083 0.33573157 0.50421982 ... 0.29072815 0.29568567 0.32740515]
#  [0.58821448 0.68151794 0.47378134 ... 0.28356659 0.23231793 0.29463336]
#  ...
#  [0.71203015 0.34515799 0.42251984 ... 0.38713858 0.28549155 0.30457196]
#  [0.55336237 0.36122729 0.39733545 ... 0.33640057 0.26739978 0.23419659]
#  [0.71365186 0.35252881 0.59155164 ... 0.42479147 0.20740147 0.35707782]]

# %%
data2 = np.mean(data2, axis=0)
first_var2 = np.mean(first_var2, axis=0)
second_var2 = np.mean(second_var2, axis=0)

# %%
print(first_var2)
print(second_var2)
# Out:
# [10.11579062  3.60018927  2.73760808  4.06445228  4.27623426  1.71714527
#   1.49687611  1.63392952  1.56889847  6.28978634  3.60393521  2.40288306
#   1.73699182]
# [0.16871882 0.05527544 0.08591221 0.05713079 0.06932207 0.05696859
#  0.06864111 0.05538049 0.06873082 0.05588858 0.0650623  0.0456988
#  0.04763557]

# %%
print(data2)
plt.scatter(np.arange(13), data2, label="0.2")
# Out:
# [0.7797579  0.3759666  0.46981113 0.35519659 0.41323999 0.32938643
#  0.40230512 0.3227916  0.40073617 0.34861286 0.39236006 0.29124826
#  0.32249942]

# %%
data4 = np.array([])
first_var4 = np.array([])
second_var4 = np.array([])
data4a = np.array([])
first_var4a = np.array([])
second_var4a = np.array([])
for i in range(160):
    data4 = np.append(data4, np.load("0.4/tv_0.4y9x4_param"+str(i+1)+".npy"))
    first_var4 = np.append(first_var4, np.load("0.4/tv_first_var0.4y9x4_param"+str(i+1)+".npy"))
    second_var4 = np.append(second_var4, np.load("0.4/tv_second_var0.4y9x4_param"+str(i+1)+".npy"))
    data4a = np.append(data4a, np.load("0.4a/tv_0.4y9x4_param"+str(i+1)+".npy"))
    first_var4a = np.append(first_var4a, np.load("0.4a/tv_first_var0.4y9x4_param"+str(i+1)+".npy"))
    second_var4a = np.append(second_var4a, np.load("0.4a/tv_second_var0.4y9x4_param"+str(i+1)+".npy"))

# %%
data4 = np.reshape(data4,(160, 13))
first_var4 = np.reshape(first_var4,(160, 13))
second_var4 = np.reshape(second_var4, (160, 13))
data4a = np.reshape(data4a,(160, 13))
first_var4a = np.reshape(first_var4a,(160, 13))
second_var4a = np.reshape(second_var4a, (160, 13))

# %%
data4 = np.mean(data4, axis=0)
first_var4 = np.mean(first_var4, axis=0)
second_var4 = np.mean(second_var4, axis=0)
data4a = np.mean(data4a, axis=0)
first_var4a = np.mean(first_var4a, axis=0)
second_var4a = np.mean(second_var4a, axis=0)

# %%
print(first_var4)
print(second_var4)
print(first_var4a)
print(second_var4a)
# Out:
# [5.32008140e+02 6.63538920e+02 2.99328479e+01 1.11819153e+01
#  2.05137101e+01 1.01500230e+02 1.93960169e+01 1.98869792e+01
#  3.23220566e+00 2.88272414e+01 2.81717828e+00 2.42816716e-01
#  1.56305612e+00]
# [0.19626443 0.06004551 0.08232293 0.04842616 0.05286359 0.04258217
#  0.0515941  0.03781503 0.04826607 0.0298185  0.03918478 0.01644784
#  0.02181045]
# [1.54755199e+01 6.59629092e+02 2.77474236e+00 5.39409350e+00
#  1.55298480e+01 2.43873676e+01 3.74690341e-01 1.97156962e+01
#  5.00674748e-01 7.60053449e+00 2.22170566e+00 1.63039106e-01
#  1.52067871e+00]
# [0.17525582 0.10710263 0.11703137 0.09663726 0.09479589 0.0842776
#  0.08415243 0.07301316 0.07311435 0.05704551 0.05306405 0.03349711
#  0.03059664]

# %%
import matplotlib.pyplot as plt

plt.scatter(np.arange(13), data4, label="0.4")

# %%
data45 = np.array([])
first_var45 = np.array([])
second_var45 = np.array([])
for i in range(160):
    data45 = np.append(data45, np.load("0.45/tv_0.45y9x4_param"+str(i+1)+".npy"))
    first_var45 = np.append(first_var45, np.load("0.45/tv_first_var0.45y9x4_param"+str(i+1)+".npy"))
    second_var45 = np.append(second_var45, np.load("0.45/tv_second_var0.45y9x4_param"+str(i+1)+".npy"))

# %%
data45 = np.reshape(data45,(160, 13))
print(data4)
first_var45 = np.reshape(first_var45,(160, 13))
second_var45 = np.reshape(second_var45, (160, 13))
# Out:
# [0.91607005 0.50298439 0.41314466 0.27061917 0.28960244 0.2818602
#  0.28198975 0.2234407  0.24863805 0.20687933 0.19870339 0.09174307
#  0.11381438]

# %%
data45 = np.mean(data45, axis=0)
first_var45 = np.mean(first_var45, axis=0)
second_var45= np.mean(second_var45, axis=0)

# %%
print(first_var45)
print(second_var45)
# Out:
# [215.94701157  81.66378603  13.737384    39.26127928  19.1850236
#   20.88033801  13.19329563  36.64805931  13.07017973   5.36262599
#    4.13164153  15.55160786   0.91150736]
# [0.20105457 0.06127121 0.07776596 0.08368266 0.08253243 0.0726751
#  0.07100356 0.05748503 0.06576509 0.05173696 0.05852653 0.03227114
#  0.03499007]

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(13), data45)
plt.show()

# %%
data5 = np.array([])
first_var5 = np.array([])
second_var5 = np.array([])
for i in range(160):
    data5 = np.append(data5, np.load("0.5/tv_0.5y9x4_param"+str(i+1)+".npy"))
    first_var5 = np.append(first_var5, np.load("0.5/tv_first_var0.5y9x4_param"+str(i+1)+".npy"))
    second_var5 = np.append(second_var5, np.load("0.5/tv_second_var0.5y9x4_param"+str(i+1)+".npy"))

# %%
data5 = np.reshape(data5,(160, 13))
print(data)
first_var5 = np.reshape(first_var5,(160, 13))
second_var5 = np.reshape(second_var5, (160, 13))
# Out:
# [0.72664645 0.32682856 0.46001837 0.31565466 0.43868287 0.33353055
#  0.44245837 0.3341911  0.44020836 0.33894147 0.40595916 0.2923748
#  0.33066909]

# %%
data5 = np.mean(data5, axis=0)
first_var5 = np.mean(first_var5, axis=0)
second_var5 = np.mean(second_var5, axis=0)

# %%
print(first_var5)
print(second_var5)
# Out:
# [105.1529037   13.12247606  95.43098038  74.53876469  12.03912142
#    8.07911698   5.51921226  28.77527289   5.23190413  26.95295638
#    4.92209106   2.79481881   1.24044009]
# [0.20758614 0.06148559 0.09615092 0.08632312 0.08416761 0.06241985
#  0.07465018 0.05151862 0.06534673 0.04598425 0.04975038 0.02269741
#  0.02018902]

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(13), data5)
plt.show()

# %%
data55 = np.array([])
first_var55 = np.array([])
second_var55 = np.array([])
for i in range(160):
    data55 = np.append(data55, np.load("0.55/tv_0.55y9x4_param"+str(i+1)+".npy"))
    first_var55 = np.append(first_var55, np.load("0.55/tv_first_var0.55y9x4_param"+str(i+1)+".npy"))
    second_var55 = np.append(second_var55, np.load("0.55/tv_second_var0.55y9x4_param"+str(i+1)+".npy"))

# %%
data55 = np.reshape(data55,(160, 13))
print(data55)
first_var55 = np.reshape(first_var55,(160, 13))
second_var55 = np.reshape(second_var55, (160, 13))
# Out:
# [[0.52362445 0.32007843 0.3381192  ... 0.26259488 0.15136356 0.27365939]
#  [0.90003265 0.91086163 0.72020081 ... 0.2738252  0.62612933 0.22067984]
#  [0.77678333 0.46222772 0.64859937 ... 0.26328809 0.22787076 0.16996858]
#  ...
#  [0.79310767 0.48751593 0.40866129 ... 0.28972256 0.24841751 0.17872997]
#  [0.63040369 0.31745462 0.70308691 ... 0.30065717 0.2418996  0.14815475]
#  [0.76069769 0.37642737 0.45605362 ... 0.35748169 0.25767352 0.19426221]]

# %%
data55 = np.mean(data55, axis=0)
first_var55 = np.mean(first_var55, axis=0)
second_var55 = np.mean(second_var55, axis=0)

# %%
print(first_var55)
print(second_var55)
# Out:
# [32.88148364  9.61454778 11.22514671 15.88337906 15.62696061  8.38834166
#  15.55550911 11.00030612  9.08054413 10.8952257   9.69992819  4.72872321
#   2.14616397]
# [0.21105197 0.06230363 0.1047327  0.10113531 0.0953584  0.08074584
#  0.08868806 0.07277531 0.08502435 0.07019625 0.07571546 0.05652921
#  0.04070818]

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(13), data55)
plt.show()

# %%
data55a = np.array([])
first_var55a = np.array([])
second_var55a = np.array([])
for i in range(130):
    data55a = np.append(data55a, np.load("0.55/tv_0.55y8x8_param"+str(i+1)+".npy"))
    first_var55a = np.append(first_var55a, np.load("0.55/tv_first_var0.55y8x8_param"+str(i+1)+".npy"))
    second_var55a = np.append(second_var55a, np.load("0.55/tv_second_var0.55y8x8_param"+str(i+1)+".npy"))

# %%
data55a = np.reshape(data55a,(130, 13))
print(data55)
first_var55a = np.reshape(first_var55a,(130, 13))
second_var55a = np.reshape(second_var55a, (130, 13))
# Out:
# [0.62775917 0.42959932 0.45696832 0.46340291 0.48527427 0.42580584
#  0.41409975 0.40387399 0.39895865 0.34869038 0.33539865 0.27219797
#  0.21153702]

# %%
data55a = np.mean(data55a, axis=0)
first_var55a = np.mean(first_var55a, axis=0)
second_var55a = np.mean(second_var55a, axis=0)

# %%
print(first_var55a)
print(second_var55a)
# Out:
# [0.31099564 0.09099136 0.0691821  0.08766222 0.05654907 0.0533482
#  0.04757942 0.02777284 0.04607488 0.0072682  0.00540948 0.00223967
#  0.00041615]
# [0.0281659  0.04674648 0.01383869 0.04140541 0.01856517 0.03049594
#  0.01782633 0.02576628 0.01762912 0.0050637  0.00074337 0.00060571
#  0.00011654]

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(13), data55a)
plt.show()

# %%
data6 = np.array([])
first_var6 = np.array([])
second_var6 = np.array([])
for i in range(160):
    data6 = np.append(data6, np.load("0.6/tv_0.6y9x4_param"+str(i+1)+".npy"))
    first_var6 = np.append(first_var6, np.load("0.6/tv_first_var0.6y9x4_param"+str(i+1)+".npy"))
    second_var6 = np.append(second_var6, np.load("0.6/tv_second_var0.6y9x4_param"+str(i+1)+".npy"))

# %%
data6 = np.reshape(data6,(160, 13))
print(data6)
first_var6 = np.reshape(first_var6,(160, 13))
second_var6 = np.reshape(second_var6, (160, 13))
# Out:
# [[0.529159   0.3983226  0.34360852 ... 0.27265784 0.20473679 0.1883517 ]
#  [0.87162415 0.55543127 0.63559399 ... 0.29058063 0.44271686 0.28775861]
#  [0.66277393 0.44655789 0.7710506  ... 0.31031781 0.23381499 0.26156403]
#  ...
#  [0.89733069 0.45883826 0.33848398 ... 0.45604224 0.20364847 0.1692226 ]
#  [0.59264856 0.3261875  0.65684644 ... 0.27502707 0.28651086 0.15114407]
#  [1.17251147 0.41349924 0.43577936 ... 0.46359549 0.22453931 0.39850955]]

# %%
data6 = np.mean(data6, axis=0)
first_var6 = np.mean(first_var6, axis=0)
second_var6 = np.mean(second_var6, axis=0)

# %%
print(first_var6)
print(second_var6)
# Out:
# [19.45811656  5.42508146  7.52941679  9.29566424  9.52976492  6.16304429
#   7.30974811  5.37620043  5.21402179  3.36519356  4.1291367   4.79636169
#   2.03329527]
# [0.21307569 0.06252428 0.11040576 0.10715969 0.09650357 0.0848907
#  0.09052087 0.0783751  0.08497066 0.07076877 0.07543713 0.05832113
#  0.04599335]

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(13), data6)
plt.show()

# %%
import numpy as np

# %%
data6a = np.array([])
first_var6a = np.array([])
second_var6a = np.array([])
for i in range(160):
    data6a = np.append(data6a, np.load("0.6/tv_0.6y8x8_param"+str(i+1)+".npy"))
    first_var6a = np.append(first_var6a, np.load("0.6/tv_first_var0.6y8x8_param"+str(i+1)+".npy"))
    second_var6a = np.append(second_var6a, np.load("0.6/tv_second_var0.6y8x8_param"+str(i+1)+".npy"))

# %%
data6a = np.reshape(data6a,(160, 13))
print(data6a)
first_var6a = np.reshape(first_var6a,(160, 13))
second_var6a = np.reshape(second_var6a, (160, 13))
# Out:
# [[0.20821576 0.29306888 0.11885229 ... 0.01005048 0.01180582 0.00718214]
#  [0.26898645 0.28597473 0.1445405  ... 0.01011657 0.01533078 0.00500576]
#  [0.21966019 0.28786188 0.12881209 ... 0.01299561 0.01512979 0.00381144]
#  ...
#  [0.23105585 0.30243475 0.13125192 ... 0.01430462 0.01467187 0.00573344]
#  [0.19906506 0.3281312  0.12324358 ... 0.0124785  0.01093114 0.0044255 ]
#  [0.22227911 0.2801886  0.13888022 ... 0.01140975 0.01212145 0.00664162]]

# %%
data6a = np.mean(data6a, axis=0)
first_var6a = np.mean(first_var6a, axis=0)
second_var6a = np.mean(second_var6a, axis=0)

# %%
print(first_var6a)
print(second_var6a)
# Out:
# [0.12253728 0.06647444 0.04423732 0.04953672 0.04366445 0.03422689
#  0.03734997 0.02729635 0.03524827 0.00658446 0.00161803 0.00120631
#  0.00042974]
# [0.02515309 0.0442051  0.01309323 0.04355593 0.019059   0.03238157
#  0.01987617 0.02681051 0.01958651 0.0040584  0.00065148 0.00052688
#  0.00010572]

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(13), data6a)
plt.show()

# %%
plt.scatter(np.arange(13), data, label="0.0",s=12, alpha=0.6)
plt.scatter(np.arange(13), data2, label="0.2", s=12,alpha=0.6)
plt.scatter(np.arange(13), data4, label="0.4", s=12,alpha=0.6)
plt.scatter(np.arange(13), data45, label="0.45", s=12,alpha=0.6)
plt.scatter(np.arange(13), data5, label="0.5", s=12,alpha=0.6)
plt.scatter(np.arange(13), data55, label="0.55", s=12,alpha=0.6)
plt.scatter(np.arange(13), data6, label="0.6", s=12,alpha=0.6)
plt.legend()
plt.show()

# %%
plt.plot(np.arange(13), data, label="J2=0.0", alpha=0.6)
plt.plot(np.arange(13), data2, label="J2=0.2",alpha=0.6)
plt.plot(np.arange(13), data4, label="J2=0.4",alpha=0.6)
plt.plot(np.arange(13), data45, label="J2=0.45",alpha=0.6)
plt.plot(np.arange(13), data5, label="J2=0.5",alpha=0.6)
plt.plot(np.arange(13), data55, label="J2=0.55",alpha=0.6)
plt.plot(np.arange(13), data6, label="J2=0.6",alpha=0.6)
plt.ylabel("Total variation")
plt.xlabel("distance")
plt.title("2DJ1J2_CMI", family="serif")
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(np.arange(13), np.log(data), label="0.0",alpha=0.6)
plt.plot(np.arange(13), np.log(data2), label="0.2",alpha=0.6)
plt.plot(np.arange(13), np.log(data4), label="0.4",alpha=0.6)
plt.plot(np.arange(13), np.log(data45), label="0.45",alpha=0.6)
plt.plot(np.arange(13), np.log(data5), label="0.5",alpha=0.6)
plt.plot(np.arange(13), np.log(data55), label="0.55",alpha=0.6)
plt.plot(np.arange(13), np.log(data6), label="0.6",alpha=0.6)
plt.ylabel("Log Total variation")
plt.xlabel("distance")
plt.title("2DJ1J2_CMI", family="serif")
plt.legend(loc="upper right")
plt.show()
