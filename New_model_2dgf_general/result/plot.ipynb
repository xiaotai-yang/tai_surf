# %%
import matplotlib.pyplot as plt
import numpy as np
E1 = np.load("meanE_L10cmi_pattern_ordered_random_seed3.npy")
E2 = np.load("meanE_L10cmi_pattern_ordered_random_sparsity2_seed3.npy")
E3 = np.load("meanE_L10cmi_pattern_ordered_random_sparsity3_seed3.npy")
E4 = np.load("meanE_L10cmi_pattern_ordered_random_sparsity4_seed3.npy")
E5 = np.load("meanE_L10cmi_pattern_ordered_random_sparsity5_seed3.npy")
E6 = np.load("meanE_L10cmi_pattern_ordered_random_sparsity6_seed3.npy")
En = np.load("meanE_L10cmi_pattern_ordered_random_sparsity102_seed3.npy")
plt.plot(E1, label="sparsity1")
plt.plot(E2, label="sparsity2")
plt.plot(E3, label="sparsity3")
plt.plot(E4, label="sparsity4")
plt.plot(E5, label="sparsity5")
plt.plot(E6, label="sparsity6")
plt.plot(En, label="no_decay")
plt.legend()
plt.xlabel("steps")
plt.ylabel("meanE")
plt.ylim(-105, -40)
plt.title("L=10_cmi_for_different_sparsity_graph_state")

# %%
varE1 = np.load("varE_L10cmi_pattern_ordered_random_seed3.npy")
varE2 = np.load("varE_L10cmi_pattern_ordered_random_sparsity2_seed3.npy")
varE3 = np.load("varE_L10cmi_pattern_ordered_random_sparsity3_seed3.npy")
varE4 = np.load("varE_L10cmi_pattern_ordered_random_sparsity4_seed3.npy")
varE5 = np.load("varE_L10cmi_pattern_ordered_random_sparsity5_seed3.npy")
varE6 = np.load("varE_L10cmi_pattern_ordered_random_sparsity6_seed3.npy")
varEn = np.load("varE_L10cmi_pattern_ordered_random_sparsity102_seed3.npy")

# %%
steps = varE1.shape[0]

# %%
plt.scatter(np.arange(steps),varE1, label="sparsity1",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE2, label="sparsity2",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE3, label="sparsity3",s=10, alpha=0.3)

plt.xlabel("steps")
plt.ylabel("varE")
plt.ylim(0, 20)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()

# %%
plt.scatter(np.arange(steps),varE4, label="sparsity4",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE5, label="sparsity5",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE6, label="sparsity6",s=10, alpha=0.3)
plt.xlabel("steps")
plt.ylabel("varE")
plt.ylim(0, 20)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()

# %%
plt.scatter(np.arange(steps),varEn, label="no_decay",s=10, alpha=0.5)
plt.xlabel("steps")
plt.ylabel("varE")
plt.ylim(0, 20)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()

# %%
E1 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity1_seed3.npy")
E2 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity2_seed3.npy")
E3 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity3_seed3.npy")
E4 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity4_seed3.npy")
E5 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity5_seed3.npy")
E6 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity6_seed3.npy")

# %%
E1, E2, E3, E4, E5, E6 = np.split(E6, 6)

# %%
plt.plot(E1 ,label="sparsity1")
plt.plot(E2, label="sparsity2")
plt.plot(E3, label="sparsity3")
plt.plot(E4, label="sparsity4")
plt.plot(E5, label="sparsity5")
plt.plot(E6, label="sparsity6")
plt.xlabel("steps")
plt.ylabel("meanE")
plt.ylim(-100, -40)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
varE1 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity1_seed3.npy")
varE2 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity2_seed3.npy")
varE3 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity3_seed3.npy")
varE4 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity4_seed3.npy")
varE5 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity5_seed3.npy")
varE6 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity6_seed3.npy")

# %%
varE1, varE2, varE3, varE4, varE5, varE6 = np.split(varE6, 6)
steps = varE1.shape[0]

# %%
plt.scatter(np.arange(steps),varE1, label="sparsity1",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE2, label="sparsity2",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE3, label="sparsity3",s=10, alpha=0.3)
plt.xlabel("steps")
plt.ylabel("varE")
plt.ylim(0, 50)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()

# %%
plt.scatter(np.arange(steps),varE4, label="sparsity4",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE5, label="sparsity5",s=10, alpha=0.3)
plt.scatter(np.arange(steps),varE6, label="sparsity6",s=10, alpha=0.3)
plt.xlabel("steps")
plt.ylabel("varE")
plt.ylim(0, 50)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
E1 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity1linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
E2 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity2linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
E3 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity3linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
E4 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity4linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
E5 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity5linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
E6 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity6linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
E7 = np.load("meanE_L10_units256_cmi_pattern_ordered_random_sparsity102linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
Var1 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity1linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
Var2 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity2linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
Var3 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity3linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
Var4 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity4linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
Var5 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity5linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
Var6 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity6linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")
Var7 = np.load("varE_L10_units256_cmi_pattern_ordered_random_sparsity102linear_cycle_schedule_max0.0002_min0.00005_seed3.npy")

# %%
E1, E2, E3, E4, E5, E6 = np.split(E6, 6)

# %%
plt.plot(E1, label="sparsity1")
plt.plot(E2, label="sparsity2")
plt.plot(E3, label="sparsity3")
plt.plot(E4, label="sparsity4")
plt.plot(E5, label="sparsity5")
plt.plot(E6, label="sparsity6")
plt.plot(E7, label="no_decay")
plt.legend()
plt.xlabel("steps")
plt.ylabel("meanE")
plt.ylim(-105, -40)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
# Out:
# Text(0.5, 1.0, 'L=10_cmi_for_different_sparsity_graph_state')

# %%
Var1, Var2, Var3, Var4, Var5, Var6 = np.split(Var6, 6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Var1, Var2, Var3, Var4, Var5, Var6 = np.split(Var6, 6)
#       2 steps = varE1.shape[0]
#
# File <__array_function__ internals>:180, in split(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\shape_base.py:872, in split(ary, indices_or_sections, axis)
#     870     N = ary.shape[axis]
#     871     if N % sections:
# --> 872         raise ValueError(
#     873             'array split does not result in an equal division') from None
#     874 return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %%
steps = Var1.shape[0]

# %%
plt.scatter(np.arange(steps),Var1, label="sparsity1",s=10, alpha=0.3)
plt.scatter(np.arange(steps),Var2, label="sparsity2",s=10, alpha=0.3)
plt.scatter(np.arange(steps),Var3, label="sparsity3",s=10, alpha=0.3)
plt.xlabel("steps")
plt.ylabel("varE")
plt.ylim(0, 20)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()

# %%
plt.scatter(np.arange(steps),Var4, label="sparsity4",s=10, alpha=0.3)
plt.scatter(np.arange(steps),Var5, label="sparsity5",s=10, alpha=0.3)
plt.scatter(np.arange(steps),Var6, label="sparsity6",s=10, alpha=0.3)
plt.scatter(np.arange(steps),Var7, label="no_decay",s=10, alpha=0.3)
plt.xlabel("steps")
plt.ylabel("varE")
plt.ylim(0, 40)
plt.title("L=10_cmi_for_different_sparsity_graph_state")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
meanE = np.load("meanE_L8_units64rotationTrueangle1.2566370614359172_seed3.npy")
E2 = np.load("meanE_L8_units64_rotationFalse_angle_1.57_seed1.npy")
E005 = np.load("meanE_L8_units64_rotationTrue_angle0.15707963267948966_seed1.npy")
E1 = np.load("meanE_L8_units64_rotationFalse_angle0.0_seed1.npy")

# %%
meanE = meanE.reshape(8 ,-1)
for i in range (meanE.shape[0]):
    plt.plot(meanE[i], label = str(i))
plt.ylim(-64, -32)
plt.legend()
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
meanE005 = np.append(E005, meanE)
meanE1 = np.append(E1, meanE005)
meanE2 = np.append(meanE1, E2)
meanE2 = meanE2.reshape(11, -1)
np.save("../../patched_rnn_rwkv/result/meanE_L8_rnn.npy", meanE2)
plt.plot(meanE2.ravel())
plt.ylim(-64, -40)
plt.ylabel("Energy")
plt.title("Different basis comparison 2D GF with L = 8")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(E1)
# Out:
# [  0.3821714 +0.26990378j  -0.45469683-0.44143972j
#    0.29634595-0.16079989j ... -63.924442  +0.01149828j
#  -63.92144   -0.04955783j -63.92479   +0.03397903j]

# %%
plt.plot(E1)
plt.ylim(-64, -48)
# Out:
# (-64.0, -48.0)
