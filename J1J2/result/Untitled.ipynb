# %%
import numpy as np

# %%
data_0 = np.array([])
first_var_0 = np.array([])
second_var_0 = np.array([])
for i in range(40):
    data_0 = np.append(data_0, np.load("0.0/tv_0.0position_80_param"+str(i+1)+".npy"))
    first_var_0 = np.append(first_var_0, np.load("0.0/tv_first_var0.0position_80param"+str(i+1)+".npy"))
    second_var_0 = np.append(second_var_0, np.load("0.0/tv_second_var0.0position_80param"+str(i+1)+".npy"))

# %%
data_0 = np.reshape(data_0,(40, 61))
print(data_0)
first_var_0 = np.reshape(first_var_0,(40, 61))
second_var_0 = np.reshape(second_var_0, (40, 61))
# Out:
# [[0.62396167 0.23059082 0.30330835 ... 0.10241417 0.10296654 0.13479749]
#  [0.60509717 0.19923074 0.34990958 ... 0.10096308 0.10192169 0.09773186]
#  [0.74205933 0.22075839 0.31179681 ... 0.09610738 0.11443573 0.10324597]
#  ...
#  [0.67254028 0.27760541 0.26350388 ... 0.10995718 0.11903297 0.09206544]
#  [0.68616785 0.24861462 0.33360037 ... 0.10492358 0.10411436 0.09144333]
#  [0.54927856 0.26585318 0.37885748 ... 0.10922574 0.1146619  0.09874371]]

# %%
data_0 = np.mean(data_0, axis=0)
first_var_0 = np.mean(first_var_0, axis=0)
second_var_0 = np.mean(second_var_0, axis=0)

# %%
print(first_var_0)
print(second_var_0)
# Out:
# [1.51219547 0.11701797 0.26343705 0.17432354 0.14298544 0.12834848
#  0.0976208  0.09482957 0.07959048 0.09262359 0.07663968 0.08165238
#  0.07640041 0.0821491  0.06415375 0.07627578 0.056952   0.068579
#  0.05430136 0.06679548 0.05287138 0.06000922 0.04884698 0.05806516
#  0.04300193 0.0512028  0.04089195 0.05452834 0.0417655  0.04759405
#  0.0386976  0.04451579 0.04274755 0.04256244 0.03916891 0.04331777
#  0.03751276 0.04348363 0.03487881 0.04195174 0.03127277 0.03930386
#  0.03024085 0.03711387 0.03141317 0.03181179 0.02569235 0.0310708
#  0.02912794 0.02834214 0.02753591 0.02851538 0.02396083 0.02446891
#  0.02137977 0.0267584  0.02077919 0.02408181 0.02052889 0.02195392
#  0.01953513]
# [0.1122875  0.02046475 0.04602917 0.01856655 0.03071046 0.01726722
#  0.02421413 0.01588442 0.02074875 0.01483103 0.0183192  0.01365022
#  0.01685544 0.01310472 0.0154276  0.01272072 0.01441203 0.01203038
#  0.01356749 0.01172039 0.01285005 0.011147   0.01218615 0.01085883
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(59)+2, data_0[2:])

plt.show()

# %%
data_2 = np.array([])
first_var_2 = np.array([])
second_var_2 = np.array([])
for i in range(80):
    data_2 = np.append(data_2, np.load("0.2/tv_0.2position_80_param"+str(i+1)+".npy"))
    first_var_2 = np.append(first_var_2, np.load("0.2/tv_first_var0.2position_80param"+str(i+1)+".npy"))
    second_var_2 = np.append(second_var_2, np.load("0.2/tv_second_var0.2position_80param"+str(i+1)+".npy"))

# %%
data_2 = np.reshape(data_2,(80, 65))
print(data_2)
first_var_2 = np.reshape(first_var_2,(80, 65))
second_var_2 = np.reshape(second_var_2, (80, 65))
# Out:
# [[0.50099075 0.24317056 0.23781558 ... 0.08311691 0.12055361 0.10181844]
#  [0.59953778 0.29584311 0.3198858  ... 0.10724255 0.09592045 0.08721612]
#  [0.48850247 0.24814032 0.21823807 ... 0.09665473 0.1140886  0.10771845]
#  ...
#  [0.49057672 0.45669281 0.25646442 ... 0.08319371 0.10253094 0.10442998]
#  [0.78065692 0.28271014 0.30332117 ... 0.10689597 0.10140905 0.08137741]
#  [0.62585895 0.21581776 0.38204422 ... 0.07301101 0.12892108 0.09215932]]

# %%
data_2 = np.mean(data_2, axis=0)
first_var_2 = np.mean(first_var_2, axis=0)
second_var_2 = np.mean(second_var_2, axis=0)

# %%
print(first_var_2)
print(second_var_2)
# Out:
# [3.75139305 0.19600103 0.29354254 0.13302205 0.14450809 0.11095187
#  0.12690044 0.09917421 0.08315725 0.06887678 0.07715317 0.07064715
#  0.06254539 0.07080053 0.07655584 0.07413266 0.06101472 0.06343128
#  0.05374138 0.05984229 0.06029772 0.05982426 0.05013665 0.05836932
#  0.05463217 0.05730937 0.05276962 0.05539238 0.04410041 0.05399993
#  0.0489298  0.0475857  0.04595154 0.05054507 0.04813684 0.04180737
#  0.04182232 0.0379514  0.04441414 0.04015564 0.03638894 0.04072752
#  0.03509674 0.03977494 0.03560105 0.04018525 0.03116264 0.03290689
#  0.0303492  0.03280978 0.03045555 0.03925003 0.03314015 0.02994402
#  0.02824903 0.02917557 0.02620962 0.02957941 0.02634074 0.02417798
#  0.02306847 0.0221936  0.02130514 0.02102587 0.02042363]
# [0.11244815 0.02240255 0.04297206 0.01799653 0.02784153 0.01609046
#  0.02232561 0.01510965 0.01897944 0.01398678 0.0169978  0.01346346
#  0.01567391 0.01273633 0.01472309 0.01243648 0.01382995 0.0120626
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(64)+1, data_2[1:])
plt.show()

# %%
plt.scatter(np.arange(64)+1, np.log(data_2[1:]))
plt.show()

# %%
data_24 = np.array([])
first_var_24 = np.array([])
second_var_24 = np.array([])
for i in range(100):
    data_24 = np.append(data_24, np.load("0.24/tv_0.24position_80_param"+str(i+1)+".npy"))
    first_var_24 = np.append(first_var_24, np.load("0.24/tv_first_var0.24position_80param"+str(i+1)+".npy"))
    second_var_24 = np.append(second_var_24, np.load("0.24/tv_second_var0.24position_80param"+str(i+1)+".npy"))

# %%
data_24 = np.reshape(data_24,(100, 65))
print(data_24)
first_var_24 = np.reshape(first_var_24,(100, 65))
second_var_24 = np.reshape(second_var_24, (100, 65))
# Out:
# [[0.56173412 0.25607077 0.24370338 ... 0.08385438 0.11306402 0.07889643]
#  [0.60144905 0.26462738 0.29311195 ... 0.09130397 0.10050594 0.0816197 ]
#  [0.47533745 0.26345098 0.2779681  ... 0.09601761 0.09961635 0.07836668]
#  ...
#  [0.76999939 0.3129915  0.24901724 ... 0.08878737 0.11152546 0.08458106]
#  [0.53510689 0.23420887 0.23604416 ... 0.12883401 0.12666638 0.10057752]
#  [0.53306782 0.31458023 0.29820032 ... 0.08703703 0.11724083 0.09219063]]

# %%
data_24 = np.mean(data_24, axis=0)
first_var_24 = np.mean(first_var_24, axis=0)
second_var_24 = np.mean(second_var_24, axis=0)

# %%
print(first_var_24)
print(second_var_24)
# Out:
# [4.49942404 0.25287843 0.37121337 0.11274389 0.220581   0.08719343
#  0.11594016 0.10016526 0.10348624 0.07343766 0.08082422 0.06994619
#  0.08256896 0.0582427  0.06313868 0.05555193 0.05726524 0.06201492
#  0.05585791 0.05526395 0.06133167 0.0509599  0.05201055 0.04478614
#  0.05087865 0.05102998 0.0450993  0.05317485 0.04458609 0.04505958
#  0.04733722 0.03874955 0.04013558 0.04656206 0.03508891 0.04324134
#  0.03432842 0.03607904 0.03314255 0.03542851 0.03570933 0.03871235
#  0.03239677 0.03568833 0.03559416 0.03233234 0.03240051 0.02801039
#  0.03113848 0.02717265 0.02244987 0.03107771 0.0275078  0.03257208
#  0.02564248 0.02454434 0.02763535 0.02367427 0.02301649 0.02160177
#  0.023132   0.02262645 0.01827997 0.02226912 0.01808402]
# [0.11286378 0.02258381 0.04118753 0.01785796 0.02678096 0.0157912
#  0.02115461 0.01448418 0.01843261 0.0133836  0.0164505  0.01266863
#  0.01486864 0.01210936 0.01380717 0.01167484 0.01303535 0.01132287
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(63)+2, data_24[2:])
plt.show()

# %%
plt.scatter(np.arange(63)+2, np.log(data_24[2:]))
plt.show()

# %%
data_241 = np.array([])
first_var_241 = np.array([])
second_var_241 = np.array([])
for i in range(100):
    data_241 = np.append(data_241, np.load("0.241/tv_0.241position_80_param"+str(i+1)+".npy"))
    first_var_241 = np.append(first_var_241, np.load("0.241/tv_first_var0.241position_80param"+str(i+1)+".npy"))
    second_var_241 = np.append(second_var_241, np.load("0.241/tv_second_var0.241position_80param"+str(i+1)+".npy"))

# %%
data_241 = np.reshape(data_241,(100, 65))
print(data_241)
first_var_241 = np.reshape(first_var_241,(100, 65))
second_var_241 = np.reshape(second_var_241, (100, 65))
# Out:
# [[0.51574039 0.29084538 0.25912504 ... 0.08091628 0.10050218 0.0721503 ]
#  [0.50032833 0.28734907 0.26212656 ... 0.08243254 0.09821295 0.08168355]
#  [0.57668648 0.26640869 0.22185493 ... 0.09599171 0.09952026 0.06802334]
#  ...
#  [0.75670784 0.30044479 0.21383686 ... 0.07717828 0.11139874 0.08331686]
#  [0.49192112 0.24867582 0.27451334 ... 0.08648726 0.10536574 0.08682558]
#  [0.63691696 0.22260681 0.26118025 ... 0.08602492 0.09017661 0.08540648]]

# %%
data_241 = np.mean(data_241, axis=0)
first_var_241 = np.mean(first_var_241, axis=0)
second_var_241 = np.mean(second_var_241, axis=0)

# %%
print(first_var_241)
print(second_var_241)
# Out:
# [2.98050661 0.28914713 0.39843388 0.10644961 0.20081091 0.08450859
#  0.1227404  0.08556214 0.08476818 0.06212106 0.06896709 0.0597526
#  0.07090071 0.05177494 0.05760391 0.05354778 0.04665499 0.04726415
#  0.05761232 0.05476503 0.05392798 0.04115771 0.04307505 0.04103556
#  0.03990293 0.0384926  0.03823594 0.03749844 0.0340406  0.03808334
#  0.03697969 0.03678516 0.03433714 0.03431024 0.03137228 0.03632112
#  0.02917116 0.0324082  0.0255636  0.02909446 0.02764017 0.03027345
#  0.02935482 0.02665214 0.02606712 0.02471803 0.02567986 0.02419985
#  0.02406111 0.02108671 0.02125091 0.02363618 0.02254778 0.02420233
#  0.02123416 0.02194751 0.0228761  0.01907058 0.0178631  0.0173156
#  0.01828703 0.01756299 0.01693314 0.01434765 0.0143651 ]
# [0.11218734 0.02248351 0.04021549 0.0173218  0.02539249 0.01499298
#  0.01972975 0.01385557 0.01707966 0.01285416 0.01494414 0.0118843
#  0.01356091 0.01133168 0.01252968 0.01075977 0.01167976 0.01030951
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(64)+1, data_241[1:])
plt.show()

# %%
plt.scatter(np.arange(64)+1, np.log(data_241[1:]))
plt.show()

# %%
data_2411 = np.array([])
first_var_2411 = np.array([])
second_var_2411 = np.array([])
for i in range(100):
    data_2411 = np.append(data_2411, np.load("0.2411/tv_0.2411position_80_param"+str(i+1)+".npy"))
    first_var_2411 = np.append(first_var_2411, np.load("0.2411/tv_first_var0.2411position_80param"+str(i+1)+".npy"))
    second_var_2411 = np.append(second_var_2411, np.load("0.2411/tv_second_var0.2411position_80param"+str(i+1)+".npy"))

# %%
data_2411 = np.reshape(data_2411,(100, 65))
print(data_2411)
first_var_2411 = np.reshape(first_var_2411,(100, 65))
second_var_2411 = np.reshape(second_var_2411, (100, 65))
# Out:
# [[0.36804981 0.32908367 0.11312402 ... 0.03728737 0.07919974 0.03958234]
#  [0.42098522 0.31895655 0.11117574 ... 0.03146394 0.1024999  0.02112363]
#  [0.34727543 0.28945248 0.13411629 ... 0.03540958 0.09734179 0.02908654]
#  ...
#  [0.40282146 0.31904238 0.09650457 ... 0.03477045 0.08989306 0.02958469]
#  [0.39160469 0.28872135 0.10040034 ... 0.03233461 0.08125844 0.0428292 ]
#  [0.34672634 0.28812284 0.14501694 ... 0.04047933 0.08112761 0.03789078]]

# %%
data_2411 = np.mean(data_2411, axis=0)
first_var_2411 = np.mean(first_var_2411, axis=0)
second_var_2411 = np.mean(second_var_2411, axis=0)

# %%
print(first_var_2411)
print(second_var_2411)
# Out:
# [0.09790404 0.03202165 0.53990753 0.14571239 0.13919357 0.10406251
#  0.10581517 0.0740044  0.06503474 0.01896908 0.02165122 0.03984788
#  0.01794273 0.12938159 0.06030665 0.04603912 0.01619209 0.02932517
#  0.0143533  0.01689604 0.01376269 0.03590943 0.01185002 0.03289409
#  0.0128516  0.01476465 0.01321319 0.01491467 0.01117037 0.0179792
#  0.011097   0.01440658 0.01082706 0.01545591 0.01043005 0.04305254
#  0.00990196 0.04256659 0.00930208 0.01662566 0.00951783 0.01896981
#  0.01013703 0.02151128 0.01361658 0.01365845 0.06263948 0.0169399
#  0.00897846 0.01647448 0.00838294 0.01538786 0.00822412 0.01295333
#  0.0082027  0.01279148 0.00793882 0.01343315 0.00649687 0.01239981
#  0.00601044 0.01566786 0.00738527 0.01218382 0.02346153]
# [0.05857444 0.02701397 0.0171776  0.02670101 0.01168087 0.02633859
#  0.00991639 0.02639176 0.00916488 0.02646758 0.00879396 0.02652038
#  0.00887744 0.026032   0.0088646  0.02587506 0.00883593 0.0254221
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(64)+1, data_2411[1:])
plt.show()

# %%
plt.scatter(np.arange(64)+1, np.log(data_2411[1:]))
plt.show()

# %%
data_2412 = np.array([])
first_var_2412 = np.array([])
second_var_2412 = np.array([])
for i in range(100):
    data_2412 = np.append(data_2412, np.load("0.2412/tv_0.2412position_80_param"+str(i+1)+".npy"))
    first_var_2412 = np.append(first_var_2412, np.load("0.2412/tv_first_var0.2412position_80param"+str(i+1)+".npy"))
    second_var_2412 = np.append(second_var_2412, np.load("0.2412/tv_second_var0.2412position_80param"+str(i+1)+".npy"))

# %%
data_2412 = np.reshape(data_2412,(100, 65))
print(data_2412)
first_var_2412 = np.reshape(first_var_2412,(100, 65))
second_var_2412 = np.reshape(second_var_2412, (100, 65))
# Out:
# [[0.58161812 0.22316511 0.29965105 ... 0.0873306  0.10851983 0.08187631]
#  [0.67816093 0.26803659 0.30644535 ... 0.09756745 0.09513412 0.09295006]
#  [0.4722237  0.25190605 0.25236385 ... 0.11377238 0.10181241 0.08202724]
#  ...
#  [0.89365974 0.23808514 0.24873596 ... 0.09270892 0.09653443 0.08589582]
#  [0.50075443 0.2307188  0.22866661 ... 0.14090208 0.10373408 0.11241073]
#  [0.52975067 0.28093405 0.29181721 ... 0.08444784 0.12404955 0.09433244]]

# %%
data_2412 = np.mean(data_2412, axis=0)
first_var_2412 = np.mean(first_var_2412, axis=0)
second_var_2412 = np.mean(second_var_2412, axis=0)

# %%
print(first_var_2412)
print(second_var_2412)
# Out:
# [4.82120374 0.40989671 0.31999459 0.10655288 0.18992829 0.10296758
#  0.13716574 0.09506307 0.08148721 0.07649654 0.078919   0.06509511
#  0.0756662  0.0651477  0.05971065 0.05295804 0.05839354 0.05879137
#  0.05179614 0.05212532 0.05551311 0.04818977 0.05413103 0.03932927
#  0.04359818 0.04619207 0.03951164 0.05929894 0.04071624 0.04524278
#  0.04337693 0.0402231  0.04433571 0.04225006 0.03127827 0.0423648
#  0.02943769 0.03578975 0.03378468 0.03522063 0.03498002 0.03919503
#  0.02907973 0.03296001 0.03422016 0.03368814 0.02889606 0.02807102
#  0.02814512 0.02689168 0.02144172 0.02785292 0.02528352 0.03305179
#  0.02358601 0.02354232 0.02398496 0.02234334 0.02177334 0.02033332
#  0.02425286 0.02145402 0.01873234 0.01975672 0.0170438 ]
# [0.1135737  0.02272947 0.041872   0.01761885 0.02658304 0.01554342
#  0.02101474 0.01437602 0.01820992 0.01320725 0.01613444 0.01258231
#  0.01466723 0.01207353 0.01352635 0.01148159 0.01276689 0.01119011
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(64)+1, data_2412[1:])
plt.show()

# %%
plt.scatter(np.arange(64)+1, np.log(data_2412[1:]))
plt.show()

# %%
data_242 = np.array([])
first_var_242 = np.array([])
second_var_242 = np.array([])
for i in range(100):
    data_242 = np.append(data_242, np.load("0.242/tv_0.242position_80_param"+str(i+1)+".npy"))
    first_var_242 = np.append(first_var_242, np.load("0.242/tv_first_var0.242position_80param"+str(i+1)+".npy"))
    second_var_242 = np.append(second_var_242, np.load("0.242/tv_second_var0.242position_80param"+str(i+1)+".npy"))
data_242 = np.reshape(data_242,(100, 65))
first_var_242 = np.reshape(first_var_242,(100, 65))
second_var_242 = np.reshape(second_var_242, (100, 65))    
data_242 = np.mean(data_242, axis=0)
first_var_242 = np.mean(first_var_242, axis=0)
second_var_242 = np.mean(second_var_242, axis=0)

# %%
print(first_var_242)
print(second_var_242)
# Out:
# [4.67637834 0.25074806 0.31725736 0.1158519  0.22029363 0.0939773
#  0.12942243 0.10755416 0.11600642 0.0825982  0.08736687 0.07607346
#  0.09502114 0.06539749 0.07237758 0.06496918 0.0606853  0.06023735
#  0.06590095 0.06365423 0.06891049 0.05594529 0.06163905 0.05429754
#  0.05041513 0.05960636 0.04758692 0.05606102 0.04691722 0.05141184
#  0.05353901 0.04836518 0.04578251 0.05761694 0.04176178 0.05048886
#  0.04162626 0.04203681 0.03647517 0.04245797 0.04109327 0.05040772
#  0.0390519  0.04517667 0.03826811 0.03985556 0.03778165 0.03483813
#  0.03582572 0.03251327 0.02763356 0.03566123 0.0310486  0.03841306
#  0.031576   0.03150106 0.0357178  0.02842463 0.02918587 0.02702393
#  0.02925091 0.02708194 0.02292553 0.02318673 0.02126189]
# [0.11358441 0.02277601 0.04243111 0.01824847 0.02786658 0.01618631
#  0.02216832 0.01512103 0.01943173 0.01405152 0.01741316 0.01340489
#  0.01576565 0.01276927 0.01480216 0.0124154  0.01403588 0.01204973
# ...

# %%
data_25 = np.array([])
first_var_25 = np.array([])
second_var_25 = np.array([])
for i in range(100):
    data_25 = np.append(data_25, np.load("0.25/tv_0.25position_80_param"+str(i+1)+".npy"))
    first_var_25 = np.append(first_var_25, np.load("0.25/tv_first_var0.25position_80param"+str(i+1)+".npy"))
    second_var_25 = np.append(second_var_25, np.load("0.25/tv_second_var0.25position_80param"+str(i+1)+".npy"))

# %%
data_25 = np.reshape(data_25,(100, 65))
print(data_25)
first_var_25 = np.reshape(first_var_25,(100, 65))
second_var_25 = np.reshape(second_var_25, (100, 65))
# Out:
# [[0.54497112 0.28018799 0.23301685 ... 0.09739637 0.1232478  0.09320219]
#  [0.71922668 0.25370014 0.33020016 ... 0.10193524 0.10640215 0.08645116]
#  [0.5033157  0.26259996 0.24995598 ... 0.10623681 0.11101195 0.08252162]
#  ...
#  [0.83974327 0.31483788 0.26066845 ... 0.10055664 0.13149733 0.09047276]
#  [0.53737446 0.25584774 0.24377399 ... 0.15614873 0.12492842 0.11610962]
#  [0.5184816  0.31800465 0.28103464 ... 0.09795403 0.11068512 0.10082678]]

# %%
data_25 = np.mean(data_25, axis=0)
first_var_25 = np.mean(first_var_25, axis=0)
second_var_25 = np.mean(second_var_25, axis=0)

# %%
print(first_var_241)
print(second_var_241)
# Out:
# [2.98050661 0.28914713 0.39843388 0.10644961 0.20081091 0.08450859
#  0.1227404  0.08556214 0.08476818 0.06212106 0.06896709 0.0597526
#  0.07090071 0.05177494 0.05760391 0.05354778 0.04665499 0.04726415
#  0.05761232 0.05476503 0.05392798 0.04115771 0.04307505 0.04103556
#  0.03990293 0.0384926  0.03823594 0.03749844 0.0340406  0.03808334
#  0.03697969 0.03678516 0.03433714 0.03431024 0.03137228 0.03632112
#  0.02917116 0.0324082  0.0255636  0.02909446 0.02764017 0.03027345
#  0.02935482 0.02665214 0.02606712 0.02471803 0.02567986 0.02419985
#  0.02406111 0.02108671 0.02125091 0.02363618 0.02254778 0.02420233
#  0.02123416 0.02194751 0.0228761  0.01907058 0.0178631  0.0173156
#  0.01828703 0.01756299 0.01693314 0.01434765 0.0143651 ]
# [0.11218734 0.02248351 0.04021549 0.0173218  0.02539249 0.01499298
#  0.01972975 0.01385557 0.01707966 0.01285416 0.01494414 0.0118843
#  0.01356091 0.01133168 0.01252968 0.01075977 0.01167976 0.01030951
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(64)+1, data_25[1:])
plt.show()

# %%
plt.scatter(np.arange(64)+1, np.log(data_25[1:]))
plt.show()

# %%
data_5 = np.array([])
first_var_5 = np.array([])
second_var_5 = np.array([])
for i in range(100):
    data_5 = np.append(data_5, np.load("0.5/tv_0.5position_80_param"+str(i+1)+".npy"))
    first_var_5 = np.append(first_var_5, np.load("0.5/tv_first_var0.5position_80param"+str(i+1)+".npy"))
    second_var_5 = np.append(second_var_5, np.load("0.5/tv_second_var0.5position_80param"+str(i+1)+".npy"))

# %%
data_5 = np.reshape(data_5,(100, 65))
print(data_5)
first_var_5 = np.reshape(first_var_5,(100, 65))
second_var_5 = np.reshape(second_var_5, (100, 65))
# Out:
# [[5.01959877e-01 1.65104866e-07 3.71029973e-04 ... 1.77621841e-07
#   1.77621841e-07 1.76429749e-07]
#  [5.00353203e-01 1.66893005e-07 3.41584086e-04 ... 1.80006027e-07
#   1.74641609e-07 1.77025795e-07]
#  [4.97493210e-01 1.76429749e-07 3.55414152e-04 ... 1.77621841e-07
#   1.68085098e-07 1.82390213e-07]
#  ...
#  [4.99433212e-01 1.81198120e-07 3.47212553e-04 ... 1.70469284e-07
#   1.75237656e-07 1.77621841e-07]
#  [4.99619865e-01 1.59144402e-07 3.17955017e-04 ... 1.86562538e-07
#   1.74641609e-07 1.69277191e-07]
#  [4.98959885e-01 1.58548355e-07 4.21118736e-04 ... 1.75237656e-07
#   1.63316727e-07 1.78813934e-07]]

# %%
data_5 = np.mean(data_5, axis=0)
first_var_5 = np.mean(first_var_5, axis=0)
second_var_5 = np.mean(second_var_5, axis=0)

# %%
print(first_var_5)
print(second_var_5)
# Out:
# [1.64996287e-04 4.91562703e-15 1.31361620e-07 2.83662867e-15
#  5.39344916e-15 3.53833939e-15 3.31935009e-15 3.53053406e-15
#  3.30395261e-15 3.52866881e-15 3.59187522e-15 3.61715638e-15
#  3.58782870e-15 3.60556386e-15 3.57885451e-15 3.62700446e-15
#  3.61391271e-15 3.64962820e-15 3.57999489e-15 3.66141248e-15
#  3.60930842e-15 3.66442875e-15 3.64988757e-15 3.67924008e-15
#  3.72134323e-15 3.68682144e-15 3.63439054e-15 3.69126957e-15
#  3.73188063e-15 3.74518554e-15 3.66154037e-15 3.73074736e-15
#  3.69760406e-15 3.73973217e-15 3.67382921e-15 3.76802237e-15
#  3.77361787e-15 3.76162040e-15 3.72325462e-15 3.78610924e-15
#  3.78173940e-15 3.78393852e-15 3.73147207e-15 3.80785892e-15
#  3.78040715e-15 3.79748151e-15 3.79080590e-15 3.80186907e-15
#  3.79701249e-15 3.78777190e-15 3.81835724e-15 3.79257169e-15
#  3.80146759e-15 3.84251917e-15 3.82643253e-15 3.81658083e-15
#  3.81939460e-15 3.83103329e-15 3.81928444e-15 3.84896026e-15
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(64)+1, data_5[1:])
plt.show()

# %%
plt.scatter(np.arange(64)+1, np.log(data_5[1:]))
plt.show()

# %%
data_8 = np.array([])
first_var_8 = np.array([])
second_var_8 = np.array([])
for i in range(100):
    data_8 = np.append(data_8, np.load("0.8/tv_0.8position_80_param"+str(i+1)+".npy"))
    first_var_8 = np.append(first_var_8, np.load("0.8/tv_first_var0.8position_80param"+str(i+1)+".npy"))
    second_var_8 = np.append(second_var_8, np.load("0.8/tv_second_var0.8position_80param"+str(i+1)+".npy"))

# %%
data_8 = np.reshape(data_8,(100, 65))
print(data_8)
first_var_8 = np.reshape(first_var_8,(100, 65))
second_var_8 = np.reshape(second_var_8, (100, 65))
# Out:
# [[0.30216887 0.5666853  0.06813649 ... 0.02317223 0.0592346  0.03547849]
#  [0.33385437 0.61126053 0.06631474 ... 0.02152802 0.07583007 0.03437799]
#  [0.29833941 0.66066551 0.07758264 ... 0.03833426 0.05145281 0.02154901]
#  ...
#  [0.31268349 0.78721161 0.06286109 ... 0.02022601 0.05772938 0.03877746]
#  [0.32788914 0.61308044 0.04504479 ... 0.01631835 0.04795623 0.024712  ]
#  [0.33655949 0.62784836 0.09414865 ... 0.01721364 0.02695493 0.03147005]]

# %%
data_8 = np.mean(data_8, axis=0)
first_var_8 = np.mean(first_var_8, axis=0)
second_var_8 = np.mean(second_var_8, axis=0)

# %%
print(first_var_8)
print(second_var_8)
# Out:
# [2.89264772e-01 1.95621644e-01 2.58035058e-02 7.07032232e-02
#  6.18393149e+00 3.63810721e-01 3.99796656e-02 1.63203028e+00
#  2.73616671e-02 3.83332180e-02 1.36212710e-02 3.00556075e-02
#  1.42030043e-02 2.11728840e-02 9.07742525e-03 2.31546755e-02
#  7.39068583e-03 1.18542821e-02 4.62616474e-03 2.01950533e-02
#  5.09384070e-03 8.86190625e-03 1.01254435e-02 1.80952379e-02
#  8.48409806e-03 8.07071412e-03 4.28373852e-03 1.69505996e-02
#  4.94759744e-03 7.71936442e-03 7.65035944e-03 1.51662391e-02
#  3.50387134e-03 7.79510321e-03 4.30126474e-03 1.56977904e-02
#  4.61914164e-03 6.74994497e-03 6.80801793e-03 1.58817551e-02
#  3.92889632e-03 7.26716969e-03 3.42742428e-03 1.45646601e-02
#  6.96636124e-03 6.42674428e-03 4.81586135e-03 1.63195964e-02
#  5.13166096e-03 7.26488208e-03 4.22509575e-03 1.32693111e-02
#  7.40678527e-03 7.09225562e-03 4.97066187e-03 4.35375077e-02
#  4.42827792e-03 7.23096622e-03 4.16118676e-03 1.23267896e-02
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(np.arange(64)+1, data_8[1:])
plt.show()

# %%
plt.scatter(np.arange(64)+1, np.log(data_8[1:]))
plt.show()

# %%
plt.scatter(np.arange(60)+1, data_0[1:], label="0.0", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_2[1:], label="0.2", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_24[1:], label="0.24", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_241[1:], label="0.241", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_2411[1:], label="0.2411", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_2412[1:], label="0.2412", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_242[1:], label="0.242", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_25[1:], label="0.25", s=12, alpha=0.5)
plt.scatter(np.arange(64)+1, data_8[1:], label="0.8", s=12, alpha=0.5)
plt.ylabel("Total variation")
plt.xlabel("distance")
plt.title("1DJ1J2_CMI", family="serif")
plt.legend()
plt.show()

# %%
plt.scatter(np.arange(61), np.log(data_0), label="0.0", s=12, alpha=0.5)
plt.scatter(np.arange(65), np.log(data_2), label="0.2", s=12, alpha=0.5)
plt.scatter(np.arange(65), np.log(data_24), label="0.24", s=12, alpha=0.5)
plt.scatter(np.arange(65), np.log(data_241), label="0.241", s=12, alpha=0.5)
plt.scatter(np.arange(65),  np.log(data_2411), label="0.2411", s=12, alpha=0.5)
plt.scatter(np.arange(65),  np.log(data_2412), label="0.2412", s=12, alpha=0.5)
plt.scatter(np.arange(65),  np.log(data_242), label="0.242", s=12, alpha=0.5)
plt.scatter(np.arange(65),  np.log(data_25), label="0.25", s=12, alpha=0.5)
plt.scatter(np.arange(65),  np.log(data_8), label="0.8", s=12, alpha=0.5)
plt.ylabel("Log Total variation")
plt.xlabel("distance")
plt.title("1DJ1J2_CMI", family="serif")
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(np.arange(61), np.log(data_0), label="J2=0.0", alpha=0.5)
plt.plot(np.arange(65), np.log(data_2), label="J2=0.2", alpha=0.5)
plt.plot(np.arange(65), np.log(data_24), label="J2=0.24", alpha=0.5)
plt.plot(np.arange(65), np.log(data_241), label="J2=0.241", alpha=0.5)
plt.plot(np.arange(65),  np.log(data_2411), label="J2=0.2411", alpha=0.5)
plt.plot(np.arange(65),  np.log(data_2412), label="J2=0.2412", alpha=0.5)
plt.plot(np.arange(65),  np.log(data_242), label="J2=0.242", alpha=0.5)
plt.plot(np.arange(65),  np.log(data_25), label="J2=0.25", alpha=0.5)
plt.plot(np.arange(65),  np.log(data_8), label="J2=0.8", alpha=0.5)
plt.ylabel("Total variation")
plt.xlabel("distance")
plt.title("1DJ1J2_CMI", family="serif")
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(np.arange(61), (data_0), label="J2=0.0", alpha=0.5)
plt.plot(np.arange(65), (data_2), label="J2=0.2", alpha=0.5)
plt.plot(np.arange(65), (data_24), label="J2=0.24", alpha=0.5)
plt.plot(np.arange(65), (data_241), label="J2=0.241", alpha=0.5)
plt.plot(np.arange(65),  (data_2411), label="J2=0.2411", alpha=0.5)
plt.plot(np.arange(65),  (data_2412), label="J2=0.2412", alpha=0.5)
plt.plot(np.arange(65),  (data_242), label="J2=0.242", alpha=0.5)
plt.plot(np.arange(65),  (data_25), label="J2=0.25", alpha=0.5)
plt.plot(np.arange(65),  (data_8), label="J2=0.8", alpha=0.5)
plt.ylabel("Total variation")
plt.xlabel("distance")
plt.title("1DJ1J2_CMI", family="serif")
plt.legend(loc="upper right")
plt.show()
