# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
name = ["0.0","0.24","0.241","0.2411","0.2412","0.25","0.8"]

# %%
data=[]
for i in range(len(name)):
    data.append(np.load("correlation_x80_J2"+str(name[i])+".npy"))

# %%
np.array(data).shape
# Out:
# (7, 81)

# %%
for i in range(7):
    plt.plot(np.arange(81), np.log(data[i]), label="J2="+name[i], alpha=0.4)
plt.legend(loc = "upper right")
