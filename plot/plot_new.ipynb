# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
E_1drnn_L16p4 = np.load("result/meanE_1Drnn_L16_patch4_units64_seed3.npy")
E_1drnn_L32p2 = np.load("result/meanE_1Drnn_L32_patch2_units64_seed3.npy")
E_1drnn_L64p1 = np.load("result/meanE_1Drnn_L64_patch1_units64_seed3.npy")
E_1drnn_dmrg_L16p4 = np.load("result/meanE_1Drnn_dmrg_L16_patch4_units64_seed3.npy")
E_1drnn_dmrg_L32p2 = np.load("result/meanE_1Drnn_dmrg_L32_patch2_units64_seed3.npy")
E_1drnn_dmrg_L64p1 = np.load("result/meanE_1Drnn_dmrg_L64_patch1_units64_seed3.npy")
E_1drwkv_L16p4 = np.load("result/meanE_1Drwkv_L16_patch4_emb16_hidden32_seed3.npy")
E_1drwkv_L32p2 = np.load("result/meanE_1Drwkv_L32_patch2_emb16_hidden32_seed3.npy")
E_1drwkv_L64p1 = np.load("result/meanE_1Drwkv_L64_patch1_emb16_hidden32_seed3.npy")
E_1drwkv_dmrg_L16p4 = np.load("result/meanE_1Drwkv_dmrg_L16_patch4_emb16_hidden32_seed3.npy")
E_1drwkv_dmrg_L32p2 = np.load("result/meanE_1Drwkv_dmrg_L32_patch2_emb16_hidden32_seed3.npy")
E_1drwkv_dmrg_L64p1 = np.load("result/meanE_1Drwkv_dmrg_L64_patch1_emb16_hidden32_seed3.npy")
E_1dTQS_L16p4 = np.load("result/meanE_1dTQS_L16_patch4_seed3.npy")
E_1dTQS_L32p2 = np.load("result/meanE_1dTQS_L32_patch2_seed3.npy")
E_1dTQS_dmrg_L16p4 = np.load("result/meanE_1dTQS_dmrg_L16_patch4_seed3.npy")
E_1dTQS_dmrg_L32p2 = np.load("result/meanE_1dTQS_dmrg_L32_patch2_seed3.npy")
E_2drnn_L4p2 = np.load("result/meanE_2Drnn_L4_patch2_units32_seed3.npy")
E_2drnn_L8p1 = np.load("result/meanE_2Drnn_L8_patch1_units32_seed3.npy")
E_2drwkv_L4p2 = np.load("result/meanE_2Drwkv_L4_patch2_seed3.npy")

varE_1drnn_L16p4 = np.load("result/varE_1Drnn_L16_patch4_units64_seed3.npy")
varE_1drnn_L32p2 = np.load("result/varE_1Drnn_L32_patch2_units64_seed3.npy")
varE_1drnn_L64p1 = np.load("result/varE_1Drnn_L64_patch1_units64_seed3.npy")
varE_1drnn_dmrg_L16p4 = np.load("result/varE_1Drnn_dmrg_L16_patch4_units64_seed3.npy")
varE_1drnn_dmrg_L32p2 = np.load("result/varE_1Drnn_dmrg_L32_patch2_units64_seed3.npy")
varE_1drnn_dmrg_L64p1 = np.load("result/varE_1Drnn_dmrg_L64_patch1_units64_seed3.npy")
varE_1drwkv_L16p4 = np.load("result/varE_1Drwkv_dmrg_L16_patch4_emb16_hidden32_seed3.npy")
varE_1drwkv_L32p2 = np.load("result/varE_1Drwkv_dmrg_L32_patch2_emb16_hidden32_seed3.npy")
varE_1drwkv_L64p1 = np.load("result/varE_1Drwkv_L64_patch1_emb16_hidden32_seed3.npy")
varE_1drwkv_dmrg_L16p4 = np.load("result/varE_1Drwkv_dmrg_L16_patch4_emb16_hidden32_seed3.npy")
varE_1drwkv_dmrg_L32p2 = np.load("result/varE_1Drwkv_dmrg_L32_patch2_emb16_hidden32_seed3.npy")
varE_1drwkv_dmrg_L64p1 = np.load("result/varE_1Drwkv_dmrg_L64_patch1_emb16_hidden32_seed3.npy")
varE_1dTQS_L16p4 = np.load("result/varE_1dTQS_L16_patch4_seed3.npy")
varE_1dTQS_L32p2 = np.load("result/varE_1dTQS_L32_patch2_seed3.npy")
varE_1dTQS_dmrg_L16p4 = np.load("result/varE_1dTQS_dmrg_L16_patch4_seed3.npy")
varE_1dTQS_dmrg_L32p2 = np.load("result/varE_1dTQS_dmrg_L32_patch2_seed3.npy")
varE_2drnn_L4p2 = np.load("result/varE_2Drnn_L4_patch2_units32_seed3.npy")
varE_2drnn_L8p1 = np.load("result/varE_2Drnn_L8_patch1_units32_seed3.npy")
varE_2drwkv_L4p2 = np.load("result/varE_2Drwkv_L4_patch2_seed3.npy")

# %%
lastE_1drnn_L16p4, lastvarE_1drnn_L16p4 = E_1drnn_L16p4.reshape(11, -1)[:, -1].real, varE_1drnn_L16p4.reshape(11, -1)[:, -1]
lastE_1drnn_L32p2, lastvarE_1drnn_L32p2 = E_1drnn_L32p2.reshape(11, -1)[:, -1].real, varE_1drnn_L32p2.reshape(11, -1)[:, -1]
lastE_1drnn_L64p1, lastvarE_1drnn_L64p1 = E_1drnn_L64p1.reshape(11, -1)[:, -1].real, varE_1drnn_L64p1.reshape(11, -1)[:, -1]
lastE_1drnn_dmrg_L16p4, lastvarE_1drnn_dmrg_L16p4 = E_1drnn_dmrg_L16p4.reshape(11, -1)[:, -1].real, varE_1drnn_dmrg_L16p4.reshape(11, -1)[:, -1]
lastE_1drnn_dmrg_L32p2, lastvarE_1drnn_dmrg_L32p2 = E_1drnn_dmrg_L32p2.reshape(11, -1)[:, -1].real, varE_1drnn_dmrg_L32p2.reshape(11, -1)[:, -1]
lastE_1drnn_dmrg_L64p1, lastvarE_1drnn_dmrg_L64p1 = E_1drnn_dmrg_L64p1.reshape(11, -1)[:, -1].real, varE_1drnn_dmrg_L64p1.reshape(11, -1)[:, -1]
lastE_1drwkv_L16p4, lastvarE_1drwkv_L16p4 = E_1drwkv_L16p4.reshape(11, -1)[:, -1].real, varE_1drwkv_L16p4.reshape(11, -1)[:, -1]
lastE_1drwkv_L32p2, lastvarE_1drwkv_L32p2 = E_1drwkv_L32p2.reshape(11, -1)[:, -1].real, varE_1drwkv_L32p2.reshape(11, -1)[:, -1]
lastE_1drwkv_L64p1, lastvarE_1drwkv_L64p1 = E_1drwkv_L64p1.reshape(11, -1)[:, -1].real, varE_1drwkv_L64p1.reshape(11, -1)[:, -1]
lastE_1drwkv_dmrg_L16p4, lastvarE_1drwkv_dmrg_L16p4 = E_1drwkv_dmrg_L16p4.reshape(11, -1)[:, -1].real, varE_1drwkv_dmrg_L16p4.reshape(11, -1)[:, -1]
lastE_1drwkv_dmrg_L32p2, lastvarE_1drwkv_dmrg_L32p2 = E_1drwkv_dmrg_L32p2.reshape(11, -1)[:, -1].real, varE_1drwkv_dmrg_L32p2.reshape(11, -1)[:, -1]
lastE_1drwkv_dmrg_L64p1, lastvarE_1drwkv_dmrg_L64p1 = E_1drwkv_dmrg_L64p1.reshape(11, -1)[:, -1].real, varE_1drwkv_dmrg_L64p1.reshape(11, -1)[:, -1]
lastE_1dTQS_L16p4, lastvarE_1dTQS_L16p4 = E_1dTQS_L16p4.reshape(11, -1)[:, -1].real, varE_1dTQS_L16p4.reshape(11, -1)[:, -1]
lastE_1dTQS_L32p2, lastvarE_1dTQS_L32p2 = E_1dTQS_L32p2.reshape(11, -1)[:, -1].real, varE_1dTQS_L32p2.reshape(11, -1)[:, -1]
lastE_1dTQS_dmrg_L16p4, lastvarE_1dTQS_dmrg_L16p4 = E_1dTQS_dmrg_L16p4.reshape(11, -1)[:, -1].real, varE_1dTQS_dmrg_L16p4.reshape(11, -1)[:, -1]
lastE_1dTQS_dmrg_L32p2, lastvarE_1dTQS_dmrg_L32p2 = E_1dTQS_dmrg_L32p2.reshape(11, -1)[:, -1].real, varE_1dTQS_dmrg_L32p2.reshape(11, -1)[:, -1]
lastE_2drnn_L4p2, lastvarE_2drnn_L4p2 = E_2drnn_L4p2.reshape(11, -1)[:, -1].real, varE_2drnn_L4p2.reshape(11, -1)[:, -1]
lastE_2drnn_L8p1, lastvarE_2drnn_L8p1 = E_2drnn_L8p1.reshape(11, -1)[:, -1].real, varE_2drnn_L8p1.reshape(11, -1)[:, -1]
lastE_2drwkv_L4p2, lastvarE_2drwkv_L4p2 = E_2drwkv_L4p2.reshape(11, -1)[:, -1].real, varE_2drwkv_L4p2.reshape(11, -1)[:, -1]

# %%
relative_error_1drnn_L64p1, relative_error_var_1drnn_L64p1 = (lastE_1drnn_L64p1 + 64) / 64 * 100, np.sqrt(lastvarE_1drnn_L64p1) / 64 * 100
relative_error_1drnn_L32p2, relative_error_var_1drnn_L32p2 = (lastE_1drnn_L32p2 + 64) / 64 * 100, np.sqrt(lastvarE_1drnn_L32p2) / 64 * 100
relative_error_1drnn_L16p4, relative_error_var_1drnn_L16p4 = (lastE_1drnn_L16p4 + 64) / 64 * 100, np.sqrt(lastvarE_1drnn_L16p4) / 64 * 100
relative_error_1drnn_dmrg_L64p1, relative_error_var_1drnn_dmrg_L64p1 = (lastE_1drnn_dmrg_L64p1 + 64) / 64 * 100, np.sqrt(lastvarE_1drnn_dmrg_L64p1) / 64 * 100
relative_error_1drnn_dmrg_L32p2, relative_error_var_1drnn_dmrg_L32p2 = (lastE_1drnn_dmrg_L32p2 + 64) / 64 * 100, np.sqrt(lastvarE_1drnn_dmrg_L32p2) / 64 * 100
relative_error_1drnn_dmrg_L16p4, relative_error_var_1drnn_dmrg_L16p4 = (lastE_1drnn_dmrg_L16p4 + 64) / 64 * 100, np.sqrt(lastvarE_1drnn_dmrg_L16p4) / 64 * 100
relative_error_1drwkv_L64p1, relative_error_var_1drwkv_L64p1 = (lastE_1drwkv_L64p1 + 64) / 64 * 100, np.sqrt(lastvarE_1drwkv_L64p1) / 64 * 100
relative_error_1drwkv_L32p2, relative_error_var_1drwkv_L32p2 = (lastE_1drwkv_L32p2 + 64) / 64 * 100, np.sqrt(lastvarE_1drwkv_L32p2) / 64 * 100
relative_error_1drwkv_L16p4, relative_error_var_1drwkv_L16p4 = (lastE_1drwkv_L16p4 + 64) / 64 * 100, np.sqrt(lastvarE_1drwkv_L16p4) / 64 * 100
relative_error_1drwkv_dmrg_L64p1, relative_error_var_1drwkv_dmrg_L64p1 = (lastE_1drwkv_dmrg_L64p1 + 64) / 64 * 100, np.sqrt(lastvarE_1drwkv_dmrg_L64p1) / 64 * 100
relative_error_1drwkv_dmrg_L32p2, relative_error_var_1drwkv_dmrg_L32p2 = (lastE_1drwkv_dmrg_L32p2 + 64) / 64 * 100, np.sqrt(lastvarE_1drwkv_dmrg_L32p2) / 64 * 100
relative_error_1drwkv_dmrg_L16p4, relative_error_var_1drwkv_dmrg_L16p4 = (lastE_1drwkv_dmrg_L16p4 + 64) / 64 * 100, np.sqrt(lastvarE_1drwkv_dmrg_L16p4) / 64 * 100
relative_error_1dTQS_L32p2, relative_error_var_1dTQS_L32p2 = (lastE_1dTQS_L32p2 + 64) / 64 * 100, np.sqrt(lastvarE_1dTQS_L32p2) / 64 * 100
relative_error_1dTQS_L16p4, relative_error_var_1dTQS_L16p4 = (lastE_1dTQS_L16p4 + 64) / 64 * 100, np.sqrt(lastvarE_1dTQS_L16p4) / 64 * 100
relative_error_1dTQS_dmrg_L32p2, relative_error_var_1dTQS_dmrg_L32p2 = (lastE_1dTQS_dmrg_L32p2 + 64) / 64 * 100, np.sqrt(lastvarE_1dTQS_dmrg_L32p2) / 64 * 100
relative_error_1dTQS_dmrg_L16p4, relative_error_var_1dTQS_dmrg_L16p4 = (lastE_1dTQS_dmrg_L16p4 + 64) / 64 * 100, np.sqrt(lastvarE_1dTQS_dmrg_L16p4) / 64 * 100
relative_error_2drnn_L4p2, relative_error_var_2drnn_L4p2 = (lastE_2drnn_L4p2 + 64) / 64 * 100, np.sqrt(lastvarE_2drnn_L4p2) / 64 * 100
relative_error_2drnn_L8p1, relative_error_var_2drnn_L8p1 = (lastE_2drnn_L8p1 + 64) / 64 * 100, np.sqrt(lastvarE_2drnn_L8p1) / 64 * 100
relative_error_2drwk_L4p2, relative_error_var_2drwk_L4p2 = (lastE_2drwkv_L4p2 + 64) / 64 * 100, np.sqrt(lastvarE_2drwkv_L4p2) / 64 * 100

# %%
plt.plot(E_1drnn_L16p4.real, label="1DrnnL16p4", alpha = 1.0)
plt.plot(E_1drnn_L32p2.real, label="1DrnnL32p2", alpha = 1.0)
plt.plot(E_1drnn_L64p1.real, label="1DrnnL64p1", alpha = 1.0)
plt.ylim(-64, -54)
plt.xlabel("steps")
plt.ylabel("Energy")
for i in np.arange(11)*6000:
    plt.plot([i, i], [-64, -10], 'k--', linewidth=0.7)
plt.legend()
plt.show()

# %%
plt.plot(E_1drnn_dmrg_L16p4.real, label="1Drnn_dmrg_L16p4")
plt.plot(E_1drnn_dmrg_L32p2.real, label="1Drnn_dmrg_L32p2")
plt.plot(E_1drnn_dmrg_L64p1.real, label="1Drnn_dmrg_L64p1")
for i in np.arange(11)*10000:
    plt.plot([i, i], [-64, -10], 'k--', linewidth=0.7)
plt.ylim(-64, -36)
plt.xlabel("steps")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
plt.plot(E_1drwkv_L16p4.real, label="1Drwkv_L16p4")
plt.plot(E_1drwkv_L32p2.real, label="1Drwkv_L32p2")
plt.plot(E_1drwkv_L64p1.real, label="1Drwkv_L64p1")
for i in np.arange(11)*5000:
    plt.plot([i, i], [-64, -10], 'k--', linewidth=0.7)
plt.ylim(-64, -36)
plt.xlabel("steps")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
plt.plot(E_1drwkv_dmrg_L16p4.real, label="1Drwkv_dmrg_L16p4")
plt.plot(E_1drwkv_dmrg_L32p2.real, label="1Drwkv_dmrg_L32p2")
plt.plot(E_1drwkv_dmrg_L64p1.real, label="1Drwkv_dmrg_L64p1")
for i in np.arange(11)*5000:
    plt.plot([i, i], [-64, -10], 'k--', linewidth=0.7)
plt.ylim(-64, -36)
plt.xlabel("steps")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
plt.plot(E_1dTQS_L16p4.real, label="1dTQS_L16p4")
plt.plot(E_1dTQS_L32p2.real, label="1dTQS_L32p2")
for i in np.arange(11)*3000:
    plt.plot([i, i], [-64, -10], 'k--', linewidth=0.7)
plt.ylim(-64, -36)
plt.xlabel("steps")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
plt.plot(E_1dTQS_dmrg_L16p4.real, label="1dTQS_dmrg_L16p4")
plt.plot(E_1dTQS_dmrg_L32p2.real, label="1dTQS_dmrg_L32p2")
for i in np.arange(11)*6000:
    plt.plot([i, i], [-64, -10], 'k--', linewidth=0.7)
plt.ylim(-64, -36)
plt.xlabel("steps")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
plt.plot(E_2drnn_L4p2.real, label="2Drnn_L4p2")
plt.plot(E_2drnn_L8p1.real, label="2Drnn_L8p1")
plt.plot(E_2drwkv_L4p2.real, label="2Drwkv_L4p2")
for i in np.arange(11)*10000:
    plt.plot([i, i], [-64, -10], 'k--', linewidth=0.7)
plt.ylim(-64, -36)
plt.xlabel("steps")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# Function to plot data
def plot_rnn_data(font_size, title_size, label_size, legend_size, tick_size, line_thickness):
    plt.rcParams.update({'font.size': font_size, 'font.family': 'serif'})
    plt.figure(figsize=(12, 8))
    # Reverse x-axis
    x_values = np.linspace(0, np.pi/2, 11)
    
    plt.plot(x_values, relative_error_1drnn_L64p1, label="RNN patch=1", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drnn_L64p1 - relative_error_var_1drnn_L64p1, 0),
        relative_error_1drnn_L64p1 + relative_error_var_1drnn_L64p1,
        alpha=0.3
    )
    
    plt.plot(x_values, relative_error_1drnn_L32p2, label="RNN patch=2", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drnn_L32p2 - relative_error_var_1drnn_L32p2, 0),
        relative_error_1drnn_L32p2 + relative_error_var_1drnn_L32p2,
        alpha=0.3
    )
    
    plt.plot(x_values, relative_error_1drnn_L16p4, label="RNN patch=4", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drnn_L16p4 - relative_error_var_1drnn_L16p4, 0),
        relative_error_1drnn_L16p4 + relative_error_var_1drnn_L16p4,
        alpha=0.3
    )
    
    plt.plot(x_values, relative_error_1drnn_dmrg_L64p1, label="RNN+DMRG patch=1", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drnn_dmrg_L64p1 - relative_error_var_1drnn_dmrg_L64p1, 0),
        relative_error_1drnn_dmrg_L64p1 + relative_error_var_1drnn_dmrg_L64p1,
        alpha=0.3
    )
    
    plt.plot(x_values, relative_error_1drnn_dmrg_L32p2, label="RNN+DMRG patch=2", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drnn_dmrg_L32p2 - relative_error_var_1drnn_dmrg_L32p2, 0),
        relative_error_1drnn_dmrg_L32p2 + relative_error_var_1drnn_dmrg_L32p2,
        alpha=0.3
    )
    
    plt.plot(x_values, relative_error_1drnn_dmrg_L16p4, label="RNN+DMRG patch=4", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drnn_dmrg_L16p4 - relative_error_var_1drnn_dmrg_L16p4, 0),
        relative_error_1drnn_dmrg_L16p4 + relative_error_var_1drnn_dmrg_L16p4,
        alpha=0.3
    )
    
    

    plt.title("Estimated Ground States Energy for Cluster State with n=64", fontsize=title_size)
    plt.xlabel(r"Rotation angle $\theta$", fontsize=label_size)
    plt.ylabel("Relative Error (%)", fontsize=label_size)
    # Set specific x-ticks for the axis
    selected_ticks = [0, np.pi / 8, np.pi / 4, 3 * np.pi / 8, np.pi / 2]
    selected_labels = ['0', '$\\pi/8$', '$\\pi/4$', '$3\\pi/8$', '$\\pi/2$']
    
    plt.xticks(ticks=selected_ticks, labels=selected_labels, fontsize=tick_size)
    plt.yticks(fontsize=tick_size)
    plt.plot([np.pi / 2, 0], [0, 0], 'k--', linewidth=line_thickness)  # Baseline for zero relative error
    plt.legend(loc='upper right', bbox_to_anchor=(1.35, 1), fontsize=legend_size)
    plt.savefig("ClusterStateOptimization.pdf", bbox_inches='tight')
    plt.show()
    plt.clf()

# Plot with specified font sizes and line thickness
plot_rnn_data(font_size=24, title_size=24, label_size=24, legend_size=20, tick_size=24, line_thickness=4)

# %%
# Function to plot data
def plot_rwkv_data(font_size, title_size, label_size, legend_size, tick_size, line_thickness):
    plt.rcParams.update({'font.size': font_size, 'font.family': 'serif'})
    plt.figure(figsize=(12, 8))

    x_values = np.linspace(0, np.pi/2, 11)
    
    plt.plot(x_values, relative_error_1drwkv_L64p1, label="rwkv patch=1", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drwkv_L64p1 - relative_error_var_1drwkv_L64p1, 0),
        relative_error_1drwkv_L64p1 + relative_error_var_1drwkv_L64p1,
        alpha=0.3
    )
    plt.plot(x_values, relative_error_1drwkv_L32p2, label="rwkv patch=2", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drwkv_L32p2 - relative_error_var_1drwkv_L32p2, 0),
        relative_error_1drwkv_L32p2 + relative_error_var_1drwkv_L32p2,
        alpha=0.3
    )
    plt.plot(x_values, relative_error_1drwkv_L16p4, label="rwkv patch=4", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drwkv_L16p4 - relative_error_var_1drwkv_L16p4, 0),
        relative_error_1drwkv_L16p4 + relative_error_var_1drwkv_L16p4,
        alpha=0.3
    )
    
    plt.plot(x_values, relative_error_1drwkv_dmrg_L64p1, label="rwkv+DMRG patch=1", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drwkv_dmrg_L64p1 - relative_error_var_1drwkv_dmrg_L64p1, 0),
        relative_error_1drwkv_dmrg_L64p1 + relative_error_var_1drwkv_dmrg_L64p1,
        alpha=0.3
    )
    plt.plot(x_values, relative_error_1drwkv_dmrg_L32p2, label="rwkv+DMRG patch=2", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drwkv_dmrg_L32p2 - relative_error_var_1drwkv_dmrg_L32p2, 0),
        relative_error_1drwkv_dmrg_L32p2 + relative_error_var_1drwkv_dmrg_L32p2,
        alpha=0.3
    )
    plt.plot(x_values, relative_error_1drwkv_dmrg_L16p4, label="rwkv+DMRG patch=4", alpha=0.8, linewidth=line_thickness)
    plt.fill_between(
        x_values,
        np.maximum(relative_error_1drwkv_dmrg_L16p4 - relative_error_var_1drwkv_dmrg_L16p4, 0),
        relative_error_1drwkv_dmrg_L16p4 + relative_error_var_1drwkv_dmrg_L16p4,
        alpha=0.3
    )
    
    plt.title("Estimated Ground States Energy for Cluster State with n=64 rwkv", fontsize=title_size)
    plt.xlabel(r"Rotation angle $\theta$", fontsize=label_size)
    plt.ylabel("Relative Error (%)", fontsize=label_size)
    # Set specific x-ticks for the axis
    selected_ticks = [0, np.pi / 8, np.pi / 4, 3 * np.pi / 8, np.pi / 2]
    selected_labels = ['0', '$\\pi/8$', '$\\pi/4$', '$3\\pi/8$', '$\\pi/2$']
    
    plt.xticks(ticks=selected_ticks, labels=selected_labels, fontsize=tick_size)
    plt.yticks(fontsize=tick_size)
    plt.plot([np.pi / 2, 0], [0, 0], 'k--', linewidth=line_thickness)  # Baseline for zero relative error
    plt.legend(loc='upper right', bbox_to_anchor=(1.35, 1), fontsize=legend_size)
    plt.savefig("ClusterStateOptimization.pdf", bbox_inches='tight')
    plt.show()
    plt.clf()

# Plot with specified font sizes and line thickness
plot_rwkv_data(font_size=24, title_size=24, label_size=24, legend_size=20, tick_size=24, line_thickness=4)

# %%
x_values = np.linspace(0, np.pi/2, 11)
# Load and plot MPS-RNN data
E_mps = np.load("../MPS_RNN/result/meanE_L64_bonddim16_cmi_pattern_no_decayrotationTrueangle1.5707964_seed3.npy")
varE_mps = np.load("../MPS_RNN/result/varE_L64_bonddim16_cmi_pattern_no_decayrotationTrueangle1.5707964_seed3.npy")
minE_mps = E_mps.reshape(11, -1)[:, 4000]
minE_var_mps = np.sqrt(varE_mps).reshape(11, -1)[:, 4000]

# Calculate relative error
relative_error_mps = (minE_mps + 64) / 64 * 100
relative_error_var_mps = minE_var_mps / 64 * 100

plt.plot(x_values, relative_error_mps, label="MPS-RNN", linewidth=line_thickness)
plt.fill_between(
    x_values,
    np.maximum(relative_error_mps - relative_error_var_mps, 0),
    relative_error_mps + relative_error_var_mps,
    alpha=0.3
)
# Add FFNN data
iters_ffnn = []
E_ffnn = []
E_var_ffnn = []
a = 11
for i in range(a):
    data_ffnn = json.load(open("../netket_1des/FFNN/FFNN" + str(i) + ".log"))
    iters = data_ffnn['Energy']['iters']
    iters_ffnn.append(iters)
    energy = data_ffnn['Energy']['Mean']['real']
    E_ffnn.append(energy)
    E_var_ffnn.append(data_ffnn['Energy']['Variance'])

lastE_ffnn = np.array(E_ffnn).reshape(11, -1)[:, -1]
lastE_var_ffnn = np.sqrt(np.array(E_var_ffnn).reshape(11, -1)[:, -1])

# Calculate relative error for FFNN data
relative_error_ffnn = (lastE_ffnn + 16) / 16 * 100
relative_error_ffnn_var = lastE_var_ffnn / 16 * 100

plt.plot(x_values, relative_error_ffnn, label="FFNN, n=16", linewidth=line_thickness)
plt.fill_between(
    x_values,
    np.maximum(relative_error_ffnn - relative_error_ffnn_var, 0),
    relative_error_ffnn + relative_error_ffnn_var,
    alpha=0.3
)

# Add RBM data
iters_rbm = []
E_rbm = []
E_var_rbm = []
a = 11
for i in range(a):
    data_rbm = json.load(open("../netket_1des/RBM" + str(i) + "L=20" + ".log"))
    iters = data_rbm['Energy']['iters']
    iters_rbm.append(iters)
    energy = data_rbm['Energy']['Mean']['real']
    E_rbm.append(energy)
    E_var_rbm.append(data_rbm['Energy']['Variance'])

lastE_rbm = np.array(E_rbm).reshape(11, -1)[:, -1]
lastE_var_rbm = np.sqrt(np.array(E_var_rbm).reshape(11, -1)[:, -1])

# Calculate relative error for RBM data
relative_error_rbm = (lastE_rbm + 20) / 20 * 100
relative_error_rbm_var = lastE_var_rbm / 20 * 100

plt.plot(x_values, relative_error_rbm, label="RBM, n=20", linewidth=line_thickness)
plt.fill_between(
    x_values,
    np.maximum(relative_error_rbm - relative_error_rbm_var, 0),
    relative_error_rbm + relative_error_rbm_var,
    alpha=0.3
)

# Finalize plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 12
#       9 relative_error_mps = (minE_mps + 64) / 64 * 100
#      10 relative_error_var_mps = minE_var_mps / 64 * 100
# ---> 12 plt.plot(x_values, relative_error_mps, label="MPS-RNN", linewidth=line_thickness)
#      13 plt.fill_between(
#      14     x_values,
#      15     np.maximum(relative_error_mps - relative_error_var_mps, 0),
#      16     relative_error_mps + relative_error_var_mps,
#      17     alpha=0.3
#      18 )
#      19 # Add FFNN data
#
# NameError: name 'line_thickness' is not defined
