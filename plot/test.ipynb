# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Ea = np.load("result/meanE_L8_units4_cmi_pattern_decayrotationTrueangle0.0_seed3_patch1.npy")
Eb = np.load("result/meanE_L8_units4_cmi_pattern_decayrotationTrueangle0.9424779_seed3_patch1.npy")
Ec = np.load("result/meanE_L8_units4_cmi_pattern_decayrotationTrueangle1.5707963267948966_seed3_patch1.npy")
varEa = np.load("result/varE_L8_units4_cmi_pattern_decayrotationTrueangle0.0_seed3_patch1.npy")
varEb = np.load("result/varE_L8_units4_cmi_pattern_decayrotationTrueangle0.9424779_seed3_patch1.npy")
varEc = np.load("result/varE_L8_units4_cmi_pattern_decayrotationTrueangle1.5707963267948966_seed3_patch1.npy")

# %%
E = np.concatenate([Ea.ravel(), Eb.ravel(), Ec.ravel()], axis=0)
plt.plot(E2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 E = np.concatenate([Ea.ravel(), Eb.ravel(), Ec.ravel()], axis=0)
# ----> 2 plt.plot(E2)
#
# NameError: name 'E2' is not defined

# %%
E1 = E1.reshape(11, -1)
E1[0] = x1[0]
varE1 = varE1.reshape(11, -1)
varE1[0] = x2[0]
E2 = E2.reshape(11, -1)
E2[0] = x1[1]
varE2 = varE2.reshape(11, -1)
varE2[0] = x2[1]
E3 = E3.reshape(11, -1)
E3[0] = x1[2]
varE3 = varE3.reshape(11, -1)
varE3[0] = x2[2]

# %%
plt.plot(E1.ravel())
plt.plot(E2.ravel())
plt.plot(E3.ravel())
plt.show()

# %%
np.save("result/meanE_1Drnn_dmrg_L64_patch1_units64_seed3.npy", E1.ravel())
np.save("result/meanE_1Drnn_dmrg_L32_patch2_units64_seed3.npy", E2.ravel())
np.save("result/meanE_1Drnn_dmrg_L16_patch4_units64_seed3.npy", E3.ravel())

# %%
plt.plot(x2[1])
